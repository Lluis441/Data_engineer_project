# %%
pip install --force-reinstall pymongo
# Out:
# Collecting pymongo
#   Using cached pymongo-4.8.0-cp38-cp38-macosx_10_9_x86_64.whl (485 kB)
# Collecting dnspython<3.0.0,>=1.16.0
#   Using cached dnspython-2.6.1-py3-none-any.whl (307 kB)
# Installing collected packages: dnspython, pymongo
#   Attempting uninstall: dnspython
#     Found existing installation: dnspython 1.16.0
#     Uninstalling dnspython-1.16.0:
#       Successfully uninstalled dnspython-1.16.0
#   Attempting uninstall: pymongo
#     Found existing installation: pymongo 3.11.0
#     Uninstalling pymongo-3.11.0:
#       Successfully uninstalled pymongo-3.11.0
# Successfully installed dnspython-2.6.1 pymongo-4.8.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests_cache==1.0.0
# Out:
# Collecting requests_cache==1.0.0
#   Using cached requests_cache-1.0.0-py3-none-any.whl (58 kB)
# Requirement already satisfied: requests>=2.22 in ./venv/lib/python3.8/site-packages (from requests_cache==1.0.0) (2.31.0)
# Requirement already satisfied: cattrs>=22.2 in ./venv/lib/python3.8/site-packages (from requests_cache==1.0.0) (24.1.1)
# Requirement already satisfied: url-normalize>=1.4 in ./venv/lib/python3.8/site-packages (from requests_cache==1.0.0) (1.4.3)
# Requirement already satisfied: platformdirs>=2.5 in ./venv/lib/python3.8/site-packages (from requests_cache==1.0.0) (4.3.3)
# Requirement already satisfied: urllib3>=1.25.5 in ./venv/lib/python3.8/site-packages (from requests_cache==1.0.0) (2.2.3)
# Requirement already satisfied: attrs>=21.2 in ./venv/lib/python3.8/site-packages (from requests_cache==1.0.0) (24.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.8/site-packages (from requests>=2.22->requests_cache==1.0.0) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.8/site-packages (from requests>=2.22->requests_cache==1.0.0) (2024.8.30)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.8/site-packages (from requests>=2.22->requests_cache==1.0.0) (3.9)
# Requirement already satisfied: exceptiongroup>=1.1.1; python_version < "3.11" in ./venv/lib/python3.8/site-packages (from cattrs>=22.2->requests_cache==1.0.0) (1.2.2)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0; python_version < "3.11" in ./venv/lib/python3.8/site-packages (from cattrs>=22.2->requests_cache==1.0.0) (4.12.2)
# Requirement already satisfied: six in ./venv/lib/python3.8/site-packages (from url-normalize>=1.4->requests_cache==1.0.0) (1.16.0)
# Installing collected packages: requests-cache
#   Attempting uninstall: requests-cache
#     Found existing installation: requests-cache 1.2.1
#     Uninstalling requests-cache-1.2.1:
#       Successfully uninstalled requests-cache-1.2.1
# Successfully installed requests-cache-1.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install statsbombpy
# Out:
# Requirement already satisfied: statsbombpy in ./venv/lib/python3.8/site-packages (1.14.0)
# Requirement already satisfied: joblib in ./venv/lib/python3.8/site-packages (from statsbombpy) (1.4.2)
# Requirement already satisfied: pandas in ./venv/lib/python3.8/site-packages (from statsbombpy) (2.0.3)
# Requirement already satisfied: inflect in ./venv/lib/python3.8/site-packages (from statsbombpy) (7.4.0)
# Requirement already satisfied: requests-cache in ./venv/lib/python3.8/site-packages (from statsbombpy) (1.0.0)
# Requirement already satisfied: requests in ./venv/lib/python3.8/site-packages (from statsbombpy) (2.31.0)
# Requirement already satisfied: tzdata>=2022.1 in ./venv/lib/python3.8/site-packages (from pandas->statsbombpy) (2024.1)
# Requirement already satisfied: numpy>=1.20.3; python_version < "3.10" in ./venv/lib/python3.8/site-packages (from pandas->statsbombpy) (1.24.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.8/site-packages (from pandas->statsbombpy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.8/site-packages (from pandas->statsbombpy) (2024.2)
# Requirement already satisfied: more-itertools>=8.5.0 in ./venv/lib/python3.8/site-packages (from inflect->statsbombpy) (10.5.0)
# Requirement already satisfied: typeguard>=4.0.1 in ./venv/lib/python3.8/site-packages (from inflect->statsbombpy) (4.3.0)
# Requirement already satisfied: typing-extensions; python_version < "3.9" in ./venv/lib/python3.8/site-packages (from inflect->statsbombpy) (4.12.2)
# Requirement already satisfied: cattrs>=22.2 in ./venv/lib/python3.8/site-packages (from requests-cache->statsbombpy) (24.1.1)
# Requirement already satisfied: urllib3>=1.25.5 in ./venv/lib/python3.8/site-packages (from requests-cache->statsbombpy) (2.2.3)
# Requirement already satisfied: url-normalize>=1.4 in ./venv/lib/python3.8/site-packages (from requests-cache->statsbombpy) (1.4.3)
# Requirement already satisfied: platformdirs>=2.5 in ./venv/lib/python3.8/site-packages (from requests-cache->statsbombpy) (4.3.3)
# Requirement already satisfied: attrs>=21.2 in ./venv/lib/python3.8/site-packages (from requests-cache->statsbombpy) (24.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.8/site-packages (from requests->statsbombpy) (2024.8.30)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.8/site-packages (from requests->statsbombpy) (3.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.8/site-packages (from requests->statsbombpy) (3.3.2)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas->statsbombpy) (1.16.0)
# Requirement already satisfied: importlib-metadata>=3.6; python_version < "3.10" in ./venv/lib/python3.8/site-packages (from typeguard>=4.0.1->inflect->statsbombpy) (8.5.0)
# Requirement already satisfied: exceptiongroup>=1.1.1; python_version < "3.11" in ./venv/lib/python3.8/site-packages (from cattrs>=22.2->requests-cache->statsbombpy) (1.2.2)
# Requirement already satisfied: zipp>=3.20 in ./venv/lib/python3.8/site-packages (from importlib-metadata>=3.6; python_version < "3.10"->typeguard>=4.0.1->inflect->statsbombpy) (3.20.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install JSON
# Out:
# ERROR: Could not find a version that satisfies the requirement JSON (from versions: none)
# ERROR: No matching distribution found for JSON
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pymongo
# Out:
# Requirement already satisfied: pymongo in ./venv/lib/python3.8/site-packages (4.8.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in ./venv/lib/python3.8/site-packages (from pymongo) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pymongo import MongoClient
import urllib.parse

# Encode the password
username = 'lluisvega1'
password = urllib.parse.quote_plus('Handbol@44')

# Update the connection URI
uri = f"mongodb+srv://{username}:{password}@cluster1.y2db3.mongodb.net/?retryWrites=true&w=majority&appName=Cluster1"

# Create a new client and connect to the server
client = MongoClient(uri)

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Connected to MongoDB!")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Connected to MongoDB!

# %%
from pymongo import MongoClient

# Create a new client and connect to the server
client = MongoClient("mongodb://localhost:27017/")

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Connected to MongoDB!")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Connected to MongoDB!

# %%
from nba_api.stats.static import teams
from nba_api.stats.endpoints import leaguegamefinder

db = client['nba_database']  # Create a new database
collection = db['games']  # Create a new collection

# Step 1: Fetch NBA teams data
nba_teams = teams.get_teams()

# Example: Use the first team's ID for simplicity (you can loop through all teams if needed)
team_id = nba_teams[0]['id']

# Step 2: Fetch recent games for the team using nba_api
gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=team_id)
games_dict = gamefinder.get_normalized_dict()

# Step 3: Insert the data into MongoDB in batches
# The 'LeagueGameFinderResults' key contains the game data
#batch_size = 100  # Adjust the batch size if needed
data = games_dict.get('LeagueGameFinderResults')

collection.insert_many(data)

print(f"Total documents inserted: {len(data)}")


# Verifying: Print a few sample documents from MongoDB
for game in collection.find().limit(5):
    print(game)
# Out:
# Total documents inserted: 3701
# {'_id': ObjectId('66e5ae4facbcd63578470f59'), 'SEASON_ID': '22024', 'TEAM_ID': 1610612737, 'TEAM_ABBREVIATION': 'ATL', 'TEAM_NAME': 'Atlanta Hawks', 'GAME_ID': '1522400064', 'GAME_DATE': '2024-07-20', 'MATCHUP': 'ATL vs. NYK', 'WL': 'L', 'MIN': 201, 'PTS': 82, 'FGM': 27, 'FGA': 78, 'FG_PCT': 0.346, 'FG3M': 16, 'FG3A': 49, 'FG3_PCT': 0.327, 'FTM': 12, 'FTA': 18, 'FT_PCT': 0.667, 'OREB': 14, 'DREB': 25, 'REB': 39, 'AST': 19, 'STL': 7, 'BLK': 3, 'TOV': 17, 'PF': 25, 'PLUS_MINUS': -6.6}
# {'_id': ObjectId('66e5ae4facbcd63578470f5a'), 'SEASON_ID': '22024', 'TEAM_ID': 1610612737, 'TEAM_ABBREVIATION': 'ATL', 'TEAM_NAME': 'Atlanta Hawks', 'GAME_ID': '1522400055', 'GAME_DATE': '2024-07-19', 'MATCHUP': 'ATL @ CHI', 'WL': 'L', 'MIN': 210, 'PTS': 99, 'FGM': 33, 'FGA': 66, 'FG_PCT': 0.5, 'FG3M': 16, 'FG3A': 35, 'FG3_PCT': 0.457, 'FTM': 17, 'FTA': 21, 'FT_PCT': 0.81, 'OREB': 8, 'DREB': 29, 'REB': 37, 'AST': 25, 'STL': 8, 'BLK': 5, 'TOV': 26, 'PF': 28, 'PLUS_MINUS': -4.0}
# {'_id': ObjectId('66e5ae4facbcd63578470f5b'), 'SEASON_ID': '22024', 'TEAM_ID': 1610612737, 'TEAM_ABBREVIATION': 'ATL', 'TEAM_NAME': 'Atlanta Hawks', 'GAME_ID': '1522400044', 'GAME_DATE': '2024-07-17', 'MATCHUP': 'ATL vs. LAL', 'WL': 'L', 'MIN': 200, 'PTS': 86, 'FGM': 27, 'FGA': 67, 'FG_PCT': 0.403, 'FG3M': 14, 'FG3A': 38, 'FG3_PCT': 0.368, 'FTM': 18, 'FTA': 24, 'FT_PCT': 0.75, 'OREB': 10, 'DREB': 28, 'REB': 38, 'AST': 19, 'STL': 7, 'BLK': 6, 'TOV': 17, 'PF': 17, 'PLUS_MINUS': 4.0}
# {'_id': ObjectId('66e5ae4facbcd63578470f5c'), 'SEASON_ID': '22024', 'TEAM_ID': 1610612737, 'TEAM_ABBREVIATION': 'ATL', 'TEAM_NAME': 'Atlanta Hawks', 'GAME_ID': '1522400021', 'GAME_DATE': '2024-07-14', 'MATCHUP': 'ATL vs. SAS', 'WL': 'L', 'MIN': 199, 'PTS': 76, 'FGM': 25, 'FGA': 72, 'FG_PCT': 0.347, 'FG3M': 10, 'FG3A': 41, 'FG3_PCT': 0.244, 'FTM': 16, 'FTA': 26, 'FT_PCT': 0.615, 'OREB': 15, 'DREB': 27, 'REB': 42, 'AST': 16, 'STL': 9, 'BLK': 6, 'TOV': 16, 'PF': 21, 'PLUS_MINUS': -3.0}
# {'_id': ObjectId('66e5ae4facbcd63578470f5d'), 'SEASON_ID': '22024', 'TEAM_ID': 1610612737, 'TEAM_ABBREVIATION': 'ATL', 'TEAM_NAME': 'Atlanta Hawks', 'GAME_ID': '1522400006', 'GAME_DATE': '2024-07-12', 'MATCHUP': 'ATL @ WAS', 'WL': 'L', 'MIN': 201, 'PTS': 88, 'FGM': 28, 'FGA': 74, 'FG_PCT': 0.378, 'FG3M': 11, 'FG3A': 39, 'FG3_PCT': 0.282, 'FTM': 21, 'FTA': 35, 'FT_PCT': 0.6, 'OREB': 7, 'DREB': 34, 'REB': 41, 'AST': 14, 'STL': 10, 'BLK': 8, 'TOV': 14, 'PF': 23, 'PLUS_MINUS': -10.2}

# %%
from pymongo import MongoClient

# Connect to MongoDB (adjust the URI if needed for cloud/remote connection)
client = MongoClient("mongodb://localhost:27017/")

# Select the database and collection
db = client['mydatabase']  # Replace 'mydatabase' with your database name
collection = db['users']   # Replace 'users' with your collection name

# Example document
user = {
    'name': 'John Doe',
    'email': 'john.doe@example.com',
    'age': 30
}

# Insert the document into the collection
result = collection.insert_one(user)

# Output the inserted document ID
print(f"User inserted with ID: {result.inserted_id}")
# Out:
# User inserted with ID: 66e5cbf5211840e3ca0b2eb3

# %%
from nba_api.stats.endpoints import ShotChartDetail
from pymongo import MongoClient

# Connect to your MongoDB server (update the URI as per your MongoDB setup)
client = MongoClient("mongodb://localhost:27017/")

# Create or access a database and collection
db = client['nba_database']  # Replace 'nba_database' with your database name
collection = db['shotchart']  # Replace 'shotchart' with your collection name

# Define player and season for the data you want to extract
player_id = 2544  # LeBron James as an example
season = '2022-23'

# Fetch ShotChartDetail data from nba_api
response = ShotChartDetail(
    team_id=0,  # Team ID can be 0 to retrieve data for all teams
    player_id=player_id,
    season_nullable=season,
    context_measure_simple='FGA'  # You can use other context measures such as 'FGM', 'PTS', etc.
)

# Convert the response data to JSON format
data = response.get_dict()

# Extract the shot chart details from the resultSets part of the response
shots_data = data['resultSets'][0]['rowSet']
headers = data['resultSets'][0]['headers']

# Transform the data into a list of dictionaries
shots_list = [dict(zip(headers, shot)) for shot in shots_data]

# Insert the list of shots into MongoDB
if shots_list:
    collection.insert_many(shots_list)
    print(f"Successfully inserted {len(shots_list)} shot entries into MongoDB.")
else:
    print("No data found to insert.")

# Close the MongoDB connection
client.close()
# Out:
# Successfully inserted 1219 shot entries into MongoDB.

# %%
import requests
from pymongo import MongoClient

# Replace 'your_api_key' with your actual API key from RapidAPI
api_key = '2a78ee5a60msh23a52443ba2956dp1fa098jsnbb9e420aeff3'
base_url = 'https://api-football-v1.p.rapidapi.com/v3'

# MongoDB setup (replace with your MongoDB connection details)
client = MongoClient("mongodb://localhost:27017/")
db = client['fifa_database']  # Change to your preferred database name
teams_collection = db['teams']
matches_collection = db['matches']

# Set up the headers for the API request
headers = {
    'x-rapidapi-host': 'api-football-v1.p.rapidapi.com',
    'x-rapidapi-key': api_key
}

# Function to get teams for a specific league and season
def get_teams(league_id, season):
    url = f"{base_url}/teams"
    querystring = {"league": league_id, "season": season}
    response = requests.get(url, headers=headers, params=querystring)
    
    if response.status_code == 200:
        teams_data = response.json()['response']
        teams_collection.insert_many(teams_data)
        print(f"Inserted {len(teams_data)} teams into MongoDB.")
    else:
        print(f"Error fetching teams: {response.text}")

# Function to get matches for a specific team
def get_matches(team_id, season):
    url = f"{base_url}/fixtures"
    querystring = {"team": team_id, "season": season}
    response = requests.get(url, headers=headers, params=querystring)
    
    if response.status_code == 200:
        matches_data = response.json()['response']
        matches_collection.insert_many(matches_data)
        print(f"Inserted {len(matches_data)} matches into MongoDB.")
    else:
        print(f"Error fetching matches: {response.status_code}")

# Example: Get teams and matches for the English Premier League (league_id = 39) in the 2022 season
league_id = 39  # Premier League ID
season = 2022

# Fetch and insert teams into MongoDB
get_teams(league_id, season)

# Example: Fetch and insert matches for a specific team (e.g., Manchester United, team_id = 33)
#team_id = 33  # Manchester United
#get_matches(team_id, season)

# Close the MongoDB connection
client.close()
# Out:
# Error fetching teams: {"message":"You are not subscribed to this API."}

# %%
from statsbombpy import sb

# %%
def transform_column_names(df):
    df.columns = [col.replace(' ', '_').lower() for col in df.columns]
    return df

# MongoDB setup (replace with your MongoDB connection details)
client = MongoClient("mongodb://localhost:27017/")
db = client['statsbomb_database']
matches_collection = db['world_cup_2018_matches']
events_collection = db['world_cup_2018_events']

# Step 1: Fetch World Cup 2018 matches
competition_id = 43
season_id = 3
matches = sb.matches(competition_id=competition_id, season_id=season_id)

# Apply column name transformation to matches DataFrame
matches = transform_column_names(matches)

# Insert matches into MongoDB
matches_dict = matches.to_dict('records')
matches_collection.insert_many(matches_dict)
print(f"Inserted {len(matches_dict)} matches into MongoDB.")

# Step 2: Fetch and insert events for each match
for match_id in matches['match_id']:
    events = sb.events(match_id=match_id)
    
    # Apply column name transformation to events DataFrame
    events = transform_column_names(events)
    
    events_dict = events.to_dict('records')
    events_collection.insert_many(events_dict)
    print(f"Inserted {len(events_dict)} events for match {match_id} into MongoDB.")

# Close the MongoDB connection
client.close()
# Out:
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 64 matches into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 4019 events for match 7585 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3986 events for match 7570 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3318 events for match 7586 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3188 events for match 7557 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3243 events for match 7542 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 4165 events for match 8656 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3573 events for match 7554 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3475 events for match 7550 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3721 events for match 7548 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3758 events for match 7578 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3287 events for match 7553 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3954 events for match 7544 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3664 events for match 7536 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3750 events for match 7555 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3742 events for match 7546 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3457 events for match 7539 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3118 events for match 7538 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 4154 events for match 7576 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 4085 events for match 7565 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3460 events for match 7551 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3550 events for match 7537 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3549 events for match 7580 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3589 events for match 8650 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 4285 events for match 7581 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3219 events for match 7549 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3320 events for match 7529 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3704 events for match 7534 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3632 events for match 7562 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 2816 events for match 7571 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3410 events for match 7569 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3351 events for match 7568 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3472 events for match 7530 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3269 events for match 7558 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3393 events for match 7583 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3576 events for match 7547 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3183 events for match 7535 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3715 events for match 7584 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3463 events for match 7545 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3376 events for match 8649 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 2978 events for match 8658 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3325 events for match 7561 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3599 events for match 7531 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 5024 events for match 7582 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3483 events for match 7552 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3097 events for match 7532 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3599 events for match 7560 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 4010 events for match 7533 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3503 events for match 7564 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3196 events for match 7579 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3671 events for match 7572 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 2875 events for match 7577 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3822 events for match 7543 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3318 events for match 7525 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 2831 events for match 7566 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3303 events for match 8651 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3708 events for match 7567 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3869 events for match 7541 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3354 events for match 8655 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 4426 events for match 8657 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3348 events for match 7540 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 4046 events for match 8652 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3605 events for match 7563 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3039 events for match 7556 into MongoDB.
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# Inserted 3831 events for match 7559 into MongoDB.

# %%
# Function to transform column names (spaces to underscores, lowercase)
def transform_column_names(df):
    df.columns = [col.replace(' ', '_').lower() for col in df.columns]
    return df

# MongoDB setup (replace with your MongoDB connection details)
client = MongoClient("mongodb://localhost:27017/")
db = client['statsbomb_database']
events_collection = db['world_cup_2018_shots']  # Use a different collection to store only shots

# Step 1: Fetch World Cup 2018 matches (if not already fetched)
competition_id = 43
season_id = 3
matches = sb.matches(competition_id=competition_id, season_id=season_id)

# Step 2: Fetch and insert only shot events for each match
for match_id in matches['match_id']:
    events = sb.events(match_id=match_id)
    
    # Filter to only include shot events (where type['name'] == 'Shot')
    shots_df = events[events['type'].apply(lambda x: x['name'] == 'Shot')].copy()
    
    # Apply column name transformation
    shots_df = transform_column_names(shots_df)
    
    # Insert only shot events into MongoDB
    shots_dict = shots_df.to_dict('records')
    events_collection.insert_many(shots_dict)
    print(f"Inserted {len(shots_dict)} shot events for match {match_id} into MongoDB.")

# Close the MongoDB connection
client.close()
# Out:
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 21
#      18 events = sb.events(match_id=match_id)
#      20 # Filter to only include shot events (where type['name'] == 'Shot')
# ---> 21 shots_df = events[events['type'].apply(lambda x: x['name'] == 'Shot')].copy()
#      23 # Apply column name transformation
#      24 shots_df = transform_column_names(shots_df)
#
# File ~/nba_project/venv/lib/python3.8/site-packages/pandas/core/series.py:4630, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4520 def apply(
#    4521     self,
#    4522     func: AggFuncType,
#    (...)
#    4525     **kwargs,
#    4526 ) -> DataFrame | Series:
#    4527     """
#    4528     Invoke function on values of Series.
#    4529
#    (...)
#    4628     dtype: float64
#    4629     """
# -> 4630     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/nba_project/venv/lib/python3.8/site-packages/pandas/core/apply.py:1025, in SeriesApply.apply(self)
#    1022     return self.apply_str()
#    1024 # self.f is Callable
# -> 1025 return self.apply_standard()
#
# File ~/nba_project/venv/lib/python3.8/site-packages/pandas/core/apply.py:1076, in SeriesApply.apply_standard(self)
#    1074     else:
#    1075         values = obj.astype(object)._values
# -> 1076         mapped = lib.map_infer(
#    1077             values,
#    1078             f,
#    1079             convert=self.convert_dtype,
#    1080         )
#    1082 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1083     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1084     #  See also GH#25959 regarding EA support
#    1085     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/nba_project/venv/lib/python3.8/site-packages/pandas/_libs/lib.pyx:2834, in pandas._libs.lib.map_infer()
#
# Cell In[13], line 21, in <lambda>(x)
#      18 events = sb.events(match_id=match_id)
#      20 # Filter to only include shot events (where type['name'] == 'Shot')
# ---> 21 shots_df = events[events['type'].apply(lambda x: x['name'] == 'Shot')].copy()
#      23 # Apply column name transformation
#      24 shots_df = transform_column_names(shots_df)
#
# TypeError: string indices must be integers

# %%
events_test=sb.events(match_id=7559)
events_test
# Out:
# /Users/lluis44/nba_project/venv/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#      ball_receipt_outcome ball_recovery_offensive  \
# 0                     NaN                     NaN
# 1                     NaN                     NaN
# 2                     NaN                     NaN
# 3                     NaN                     NaN
# 4                     NaN                     NaN
# ...                   ...                     ...
# 3826                  NaN                     NaN
# 3827                  NaN                     NaN
# 3828                  NaN                     NaN
# 3829                  NaN                     NaN
# 3830                  NaN                     NaN
#
#      ball_recovery_recovery_failure block_offensive carry_end_location  \
# 0                               NaN             NaN                NaN
# 1                               NaN             NaN                NaN
# 2                               NaN             NaN                NaN
# 3                               NaN             NaN                NaN
# 4                               NaN             NaN                NaN
# ...                             ...             ...                ...
# 3826                            NaN             NaN                NaN
# 3827                            NaN             NaN                NaN
# 3828                            NaN             NaN                NaN
# 3829                            NaN             NaN                NaN
# 3830                            NaN             NaN                NaN
#
#      counterpress dribble_nutmeg dribble_outcome dribble_overrun duel_outcome  \
# 0             NaN            NaN             NaN             NaN          NaN
# 1             NaN            NaN             NaN             NaN          NaN
# 2             NaN            NaN             NaN             NaN          NaN
# 3             NaN            NaN             NaN             NaN          NaN
# 4             NaN            NaN             NaN             NaN          NaN
# ...           ...            ...             ...             ...          ...
# 3826          NaN            NaN             NaN             NaN          NaN
# 3827          NaN            NaN             NaN             NaN          NaN
# 3828          NaN            NaN             NaN             NaN          NaN
# 3829          NaN            NaN             NaN             NaN          NaN
# 3830          NaN            NaN             NaN             NaN          NaN
#
#       ... substitution_outcome  substitution_outcome_id  \
# 0     ...                  NaN                      NaN
# 1     ...                  NaN                      NaN
# 2     ...                  NaN                      NaN
# 3     ...                  NaN                      NaN
# 4     ...                  NaN                      NaN
# ...   ...                  ...                      ...
# 3826  ...             Tactical                    103.0
# 3827  ...                  NaN                      NaN
# 3828  ...                  NaN                      NaN
# 3829  ...                  NaN                      NaN
# 3830  ...                  NaN                      NaN
#
#                     substitution_replacement substitution_replacement_id  \
# 0                                        NaN                         NaN
# 1                                        NaN                         NaN
# 2                                        NaN                         NaN
# 3                                        NaN                         NaN
# 4                                        NaN                         NaN
# ...                                      ...                         ...
# 3826  Mahmoud Abdul Monem Abdelhamid Soliman                      5257.0
# 3827                                     NaN                         NaN
# 3828                                     NaN                         NaN
# 3829                                     NaN                         NaN
# 3830                                     NaN                         NaN
#
#                                                 tactics          team team_id  \
# 0     {'formation': 4141, 'lineup': [{'player': {'id...  Saudi Arabia     799
# 1     {'formation': 4231, 'lineup': [{'player': {'id...         Egypt     774
# 2                                                   NaN         Egypt     774
# 3                                                   NaN  Saudi Arabia     799
# 4                                                   NaN         Egypt     774
# ...                                                 ...           ...     ...
# 3826                                                NaN         Egypt     774
# 3827                                                NaN         Egypt     774
# 3828                                                NaN  Saudi Arabia     799
# 3829                                                NaN         Egypt     774
# 3830                                                NaN  Saudi Arabia     799
#
#          timestamp          type under_pressure
# 0     00:00:00.000   Starting XI            NaN
# 1     00:00:00.000   Starting XI            NaN
# 2     00:00:00.000    Half Start            NaN
# 3     00:00:00.000    Half Start            NaN
# 4     00:00:00.000    Half Start            NaN
# ...            ...           ...            ...
# 3826  00:35:26.800  Substitution            NaN
# 3827  00:51:37.840      Half End            NaN
# 3828  00:51:37.840      Half End            NaN
# 3829  00:50:33.160      Half End            NaN
# 3830  00:50:33.160      Half End            NaN
#
# [3831 rows x 81 columns]

# %%
events
# Out:
#      50_50 bad_behaviour_card ball_receipt_outcome  \
# 0      NaN                NaN                  NaN
# 1      NaN                NaN                  NaN
# 2      NaN                NaN                  NaN
# 3      NaN                NaN                  NaN
# 4      NaN                NaN                  NaN
# ...    ...                ...                  ...
# 4014   NaN                NaN                  NaN
# 4015   NaN                NaN                  NaN
# 4016   NaN                NaN                  NaN
# 4017   NaN                NaN                  NaN
# 4018   NaN                NaN                  NaN
#
#      ball_recovery_recovery_failure block_deflection block_offensive  \
# 0                               NaN              NaN             NaN
# 1                               NaN              NaN             NaN
# 2                               NaN              NaN             NaN
# 3                               NaN              NaN             NaN
# 4                               NaN              NaN             NaN
# ...                             ...              ...             ...
# 4014                            NaN              NaN             NaN
# 4015                            NaN              NaN             NaN
# 4016                            NaN              NaN             NaN
# 4017                            NaN              NaN             NaN
# 4018                            NaN              NaN             NaN
#
#      carry_end_location clearance_aerial_won counterpress dribble_nutmeg  ...  \
# 0                   NaN                  NaN          NaN            NaN  ...
# 1                   NaN                  NaN          NaN            NaN  ...
# 2                   NaN                  NaN          NaN            NaN  ...
# 3                   NaN                  NaN          NaN            NaN  ...
# 4                   NaN                  NaN          NaN            NaN  ...
# ...                 ...                  ...          ...            ...  ...
# 4014                NaN                  NaN          NaN            NaN  ...
# 4015                NaN                  NaN          NaN            NaN  ...
# 4016                NaN                  NaN          NaN            NaN  ...
# 4017                NaN                  NaN          NaN            NaN  ...
# 4018                NaN                  NaN          NaN            NaN  ...
#
#      substitution_outcome substitution_outcome_id  \
# 0                     NaN                     NaN
# 1                     NaN                     NaN
# 2                     NaN                     NaN
# 3                     NaN                     NaN
# 4                     NaN                     NaN
# ...                   ...                     ...
# 4014             Tactical                   103.0
# 4015             Tactical                   103.0
# 4016                  NaN                     NaN
# 4017                  NaN                     NaN
# 4018                  NaN                     NaN
#
#               substitution_replacement  substitution_replacement_id  \
# 0                                  NaN                          NaN
# 1                                  NaN                          NaN
# 2                                  NaN                          NaN
# 3                                  NaN                          NaN
# 4                                  NaN                          NaN
# ...                                ...                          ...
# 4014                   Marcus Rashford                       3318.0
# 4015  Cristian Eduardo Zapata Valencia                       6360.0
# 4016                               NaN                          NaN
# 4017                               NaN                          NaN
# 4018                               NaN                          NaN
#
#                                                 tactics      team team_id  \
# 0     {'formation': 433, 'lineup': [{'player': {'id'...  Colombia     769
# 1     {'formation': 352, 'lineup': [{'player': {'id'...   England     768
# 2                                                   NaN   England     768
# 3                                                   NaN  Colombia     769
# 4                                                   NaN  Colombia     769
# ...                                                 ...       ...     ...
# 4014                                                NaN   England     768
# 4015                                                NaN  Colombia     769
# 4016  {'formation': 442, 'lineup': [{'player': {'id'...  Colombia     769
# 4017                                                NaN  Colombia     769
# 4018                                                NaN   England     768
#
#          timestamp            type under_pressure
# 0     00:00:00.000     Starting XI            NaN
# 1     00:00:00.000     Starting XI            NaN
# 2     00:00:00.000      Half Start            NaN
# 3     00:00:00.000      Half Start            NaN
# 4     00:00:00.000      Half Start            NaN
# ...            ...             ...            ...
# 4014  00:07:33.493    Substitution            NaN
# 4015  00:10:17.880    Substitution            NaN
# 4016  00:16:06.374  Tactical Shift            NaN
# 4017  00:31:38.320      Camera off            NaN
# 4018  00:41:49.320      Camera off            NaN
#
# [4019 rows x 83 columns]

# %%
import requests
from pymongo import MongoClient
import json

# MongoDB setup (replace with your MongoDB connection details)
client = MongoClient("mongodb://localhost:27017/")
db = client['statsbomb_database']
matches_collection = db['world_cup_2022_matches']
events_collection = db['world_cup_2022_shots']


# Download World Cup 2022 matches JSON data directly
competition_id = 43  # World Cup
season_id = 106  # 2022 Season
matches_url = f'https://raw.githubusercontent.com/statsbomb/open-data/master/data/matches/{competition_id}/{season_id}.json'

def download_events_and_filter_shots(match_id):
    events_url = f'https://raw.githubusercontent.com/statsbomb/open-data/master/data/events/{match_id}.json'
    response = requests.get(events_url)
    
    if response.status_code == 200:
        events_data = response.json()
        
        # Filter for only "Shot" events
        shot_events = [event for event in events_data if event['type']['name'] == 'Shot']
        return shot_events
    else:
        print(f"Failed to download events for match {match_id}. Status code: {response.status_code}")
        return []

# %%
response = requests.get(matches_url)
if response.status_code == 200:
    matches_data = response.json()  # This is the raw JSON data
    matches_collection.insert_many(matches_data)  # Insert directly into MongoDB
    print(f"Inserted {len(matches_data)} matches into MongoDB.")

    # Extract match_ids from the matches data
    match_ids = [match['match_id'] for match in matches_data]

    all_shots = []
    for match_id in match_ids:
        shots = download_events_and_filter_shots(match_id)
        all_shots.extend(shots)
        print(f"Inserted {len(shots)} shot events for {match_id} into MongoDB.")

    # Insert all shot events into MongoDB
    if all_shots:
        events_collection.insert_many(all_shots)
        print(f"Inserted {len(all_shots)} shot events into MongoDB.")



else:
    print(f"Failed to download JSONS. Status code: {response.status_code}")



# Close the MongoDB connection
client.close()
# Out:
# Inserted 64 matches into MongoDB.
# Inserted 24 shot events into MongoDB.

# %%
def download_events_and_filter(match_id,event_type):
    events_url = f'https://raw.githubusercontent.com/statsbomb/open-data/master/data/events/{match_id}.json'
    response = requests.get(events_url)
    
    if response.status_code == 200:
        events_data = response.json()
        
        # Filter for only "Shot" events
        events_type = [event for event in events_data if event['type']['name'] == {event_type}]
        return events_type
    else:
        print(f"Failed to download events for match {match_id}. Status code: {response.status_code}")
        return []

# %%
from pymongo import MongoClient
import requests

client = MongoClient("mongodb://localhost:27017/")

database_name='statsbomb_database'
matches_table_name='world_cup_2022_matches'
events_table_name='world_cup_2022_shots_test'

competition_id = 43 #World Cup
season_id = 106 #2022
event_type = 'Shot'

db = client[database_name]
events_collection = db[events_table_name]

match_id=3775613 #Example match_id

events = download_events_and_filter(match_id, event_type)

events
# Out:
# []

# %%
events_url = f'https://raw.githubusercontent.com/statsbomb/open-data/master/data/events/3775613.json'
response = requests.get(events_url)

if response.status_code == 200:
    events_data = response.json()
    
    # Filter for only "Shot" events
    events_type = [event for event in events_data if event['type']['name'] == event_type]
    events_type
else:
    print(f"Failed to download events for match {match_id}. Status code: {response.status_code}")
    []

# %%
event_type='Shot'

events_type = [event for event in events_data if event['type']['name'] == event_type]
events_type
# Out:
# [{'id': 'edbc2ace-c4a3-42a5-a078-02b4a3084cfe',
#   'index': 307,
#   'period': 1,
#   'timestamp': '00:06:32.901',
#   'minute': 6,
#   'second': 32,
#   'type': {'id': 16, 'name': 'Shot'},
#   'possession': 14,
#   'possession_team': {'id': 968, 'name': 'Arsenal WFC'},
#   'play_pattern': {'id': 2, 'name': 'From Corner'},
#   'team': {'id': 968, 'name': 'Arsenal WFC'},
#   'player': {'id': 15620, 'name': 'Katie McCabe'},
#   'position': {'id': 6, 'name': 'Left Back'},
#   'location': [107.2, 21.5],
#   'duration': 1.326076,
#   'related_events': ['d0e3256b-1bbf-480d-8654-f9f487fe7455'],
#   'shot': {'statsbomb_xg': 0.011721953,
#    'end_location': [120.0, 48.1, 0.0],
#    'key_pass_id': '298549a3-ffed-4844-aafa-3b6e881b6d8c',
#    'outcome': {'id': 98, 'name': 'Off T'},
#    'first_time': True,
#    'technique': {'id': 91, 'name': 'Half Volley'},
#    'type': {'id': 87, 'name': 'Open Play'},
#    'body_part': {'id': 38, 'name': 'Left Foot'},
#    'freeze_frame': [{'location': [108.4, 22.3],
#      'player': {'id': 53440, 'name': 'Esther Morgan'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'teammate': False},
#     {'location': [107.8, 37.7],
#      'player': {'id': 4865, 'name': 'Josie Green'},
#      'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#      'teammate': False},
#     {'location': [95.8, 54.4],
#      'player': {'id': 21048, 'name': 'Rosella Ayane'},
#      'position': {'id': 16, 'name': 'Left Midfield'},
#      'teammate': False},
#     {'location': [106.4, 34.0],
#      'player': {'id': 15721, 'name': 'Gemma Suzanne Davison'},
#      'position': {'id': 12, 'name': 'Right Midfield'},
#      'teammate': False},
#     {'location': [103.8, 36.7],
#      'player': {'id': 31551, 'name': 'Kit Graham'},
#      'position': {'id': 24, 'name': 'Left Center Forward'},
#      'teammate': False},
#     {'location': [110.2, 37.2],
#      'player': {'id': 4648, 'name': 'Abbie McManus'},
#      'position': {'id': 3, 'name': 'Right Center Back'},
#      'teammate': False},
#     {'location': [111.7, 41.7],
#      'player': {'id': 5074, 'name': 'Shelina Laura Zadorsky'},
#      'position': {'id': 5, 'name': 'Left Center Back'},
#      'teammate': False},
#     {'location': [105.8, 31.1],
#      'player': {'id': 49697, 'name': 'Carlotte Wubben-Moy'},
#      'position': {'id': 3, 'name': 'Right Center Back'},
#      'teammate': True},
#     {'location': [107.9, 37.0],
#      'player': {'id': 15623, 'name': 'Vivianne Miedema'},
#      'position': {'id': 23, 'name': 'Center Forward'},
#      'teammate': True},
#     {'location': [104.8, 42.9],
#      'player': {'id': 11338, 'name': 'Caitlin Jade Foord'},
#      'position': {'id': 17, 'name': 'Right Wing'},
#      'teammate': True},
#     {'location': [98.7, 54.2],
#      'player': {'id': 10192, 'name': 'Jordan Nobbs'},
#      'position': {'id': 21, 'name': 'Left Wing'},
#      'teammate': True},
#     {'location': [111.5, 40.6],
#      'player': {'id': 10650, 'name': 'Jill Roord'},
#      'position': {'id': 15, 'name': 'Left Center Midfield'},
#      'teammate': True},
#     {'location': [106.7, 62.4],
#      'player': {'id': 10658, 'name': 'Danielle van de Donk'},
#      'position': {'id': 13, 'name': 'Right Center Midfield'},
#      'teammate': True},
#     {'location': [117.7, 37.2],
#      'player': {'id': 18158, 'name': 'Rebecca Leigh Spencer'},
#      'position': {'id': 1, 'name': 'Goalkeeper'},
#      'teammate': False},
#     {'location': [96.3, 27.3],
#      'player': {'id': 15616, 'name': 'Kim Little'},
#      'position': {'id': 10, 'name': 'Center Defensive Midfield'},
#      'teammate': True},
#     {'location': [100.0, 35.3],
#      'player': {'id': 31702, 'name': 'Rianna Dean'},
#      'position': {'id': 22, 'name': 'Right Center Forward'},
#      'teammate': False},
#     {'location': [107.5, 52.3],
#      'player': {'id': 15572, 'name': 'Siri Worm'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'teammate': False},
#     {'location': [105.9, 46.4],
#      'player': {'id': 5078, 'name': 'Alanna Stephanie Kennedy'},
#      'position': {'id': 9, 'name': 'Right Defensive Midfield'},
#      'teammate': False}]}},
#  {'id': 'd75c3451-47ed-44e8-9752-e622751b7441',
#   'index': 368,
#   'period': 1,
#   'timestamp': '00:08:22.999',
#   'minute': 8,
#   'second': 22,
#   'type': {'id': 16, 'name': 'Shot'},
#   'possession': 18,
#   'possession_team': {'id': 968, 'name': 'Arsenal WFC'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 968, 'name': 'Arsenal WFC'},
#   'player': {'id': 10658, 'name': 'Danielle van de Donk'},
#   'position': {'id': 13, 'name': 'Right Center Midfield'},
#   'location': [107.1, 39.6],
#   'duration': 0.303746,
#   'related_events': ['1f9ddb5b-e584-4271-96de-519c237e973e',
#    '9b449dbb-c4b5-4186-89c3-02dd2ddb9133'],
#   'shot': {'statsbomb_xg': 0.09431854,
#    'end_location': [110.0, 39.3],
#    'key_pass_id': 'a6c7dc8f-b84b-4648-82b6-9ce5fb5496d9',
#    'technique': {'id': 95, 'name': 'Volley'},
#    'body_part': {'id': 38, 'name': 'Left Foot'},
#    'first_time': True,
#    'outcome': {'id': 96, 'name': 'Blocked'},
#    'type': {'id': 87, 'name': 'Open Play'},
#    'freeze_frame': [{'location': [98.2, 15.0],
#      'player': {'id': 15721, 'name': 'Gemma Suzanne Davison'},
#      'position': {'id': 12, 'name': 'Right Midfield'},
#      'teammate': False},
#     {'location': [108.7, 23.0],
#      'player': {'id': 5078, 'name': 'Alanna Stephanie Kennedy'},
#      'position': {'id': 9, 'name': 'Right Defensive Midfield'},
#      'teammate': False},
#     {'location': [99.6, 33.8],
#      'player': {'id': 21048, 'name': 'Rosella Ayane'},
#      'position': {'id': 16, 'name': 'Left Midfield'},
#      'teammate': False},
#     {'location': [114.1, 14.8],
#      'player': {'id': 53440, 'name': 'Esther Morgan'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'teammate': False},
#     {'location': [112.2, 20.6],
#      'player': {'id': 4865, 'name': 'Josie Green'},
#      'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#      'teammate': False},
#     {'location': [108.0, 52.8],
#      'player': {'id': 11338, 'name': 'Caitlin Jade Foord'},
#      'position': {'id': 17, 'name': 'Right Wing'},
#      'teammate': True},
#     {'location': [98.9, 27.9],
#      'player': {'id': 15623, 'name': 'Vivianne Miedema'},
#      'position': {'id': 23, 'name': 'Center Forward'},
#      'teammate': True},
#     {'location': [96.2, 47.6],
#      'player': {'id': 10404, 'name': 'Noelle Maritz'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'teammate': True},
#     {'location': [114.2, 14.4],
#      'player': {'id': 10650, 'name': 'Jill Roord'},
#      'position': {'id': 15, 'name': 'Left Center Midfield'},
#      'teammate': True},
#     {'location': [101.1, 13.1],
#      'player': {'id': 10192, 'name': 'Jordan Nobbs'},
#      'position': {'id': 21, 'name': 'Left Wing'},
#      'teammate': True},
#     {'location': [108.8, 18.0],
#      'player': {'id': 15620, 'name': 'Katie McCabe'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'teammate': True},
#     {'location': [117.5, 39.3],
#      'player': {'id': 18158, 'name': 'Rebecca Leigh Spencer'},
#      'position': {'id': 1, 'name': 'Goalkeeper'},
#      'teammate': False},
#     {'location': [110.6, 46.0],
#      'player': {'id': 15572, 'name': 'Siri Worm'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'teammate': False},
#     {'location': [110.1, 39.2],
#      'player': {'id': 5074, 'name': 'Shelina Laura Zadorsky'},
#      'position': {'id': 5, 'name': 'Left Center Back'},
#      'teammate': False},
#     {'location': [112.3, 31.9],
#      'player': {'id': 4648, 'name': 'Abbie McManus'},
#      'position': {'id': 3, 'name': 'Right Center Back'},
#      'teammate': False}]}},
#  {'id': 'ad98471f-64e5-4492-b24e-49ef83a093c7',
#   'index': 372,
#   'period': 1,
#   'timestamp': '00:08:24.354',
#   'minute': 8,
#   'second': 24,
#   'type': {'id': 16, 'name': 'Shot'},
#   'possession': 18,
#   'possession_team': {'id': 968, 'name': 'Arsenal WFC'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 968, 'name': 'Arsenal WFC'},
#   'player': {'id': 10658, 'name': 'Danielle van de Donk'},
#   'position': {'id': 13, 'name': 'Right Center Midfield'},
#   'location': [107.1, 41.7],
#   'duration': 0.923921,
#   'related_events': ['86bd0c85-655b-427a-bc2f-5a9860b88dee'],
#   'shot': {'statsbomb_xg': 0.14263213,
#    'end_location': [116.4, 41.9, 0.0],
#    'technique': {'id': 91, 'name': 'Half Volley'},
#    'first_time': True,
#    'outcome': {'id': 100, 'name': 'Saved'},
#    'type': {'id': 87, 'name': 'Open Play'},
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'freeze_frame': [{'location': [112.2, 16.8],
#      'player': {'id': 53440, 'name': 'Esther Morgan'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'teammate': False},
#     {'location': [110.0, 21.4],
#      'player': {'id': 4865, 'name': 'Josie Green'},
#      'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#      'teammate': False},
#     {'location': [108.2, 24.7],
#      'player': {'id': 5078, 'name': 'Alanna Stephanie Kennedy'},
#      'position': {'id': 9, 'name': 'Right Defensive Midfield'},
#      'teammate': False},
#     {'location': [99.4, 33.6],
#      'player': {'id': 21048, 'name': 'Rosella Ayane'},
#      'position': {'id': 16, 'name': 'Left Midfield'},
#      'teammate': False},
#     {'location': [112.2, 34.3],
#      'player': {'id': 4648, 'name': 'Abbie McManus'},
#      'position': {'id': 3, 'name': 'Right Center Back'},
#      'teammate': False},
#     {'location': [110.0, 41.3],
#      'player': {'id': 5074, 'name': 'Shelina Laura Zadorsky'},
#      'position': {'id': 5, 'name': 'Left Center Back'},
#      'teammate': False},
#     {'location': [110.5, 46.1],
#      'player': {'id': 15572, 'name': 'Siri Worm'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'teammate': False},
#     {'location': [117.1, 41.3],
#      'player': {'id': 18158, 'name': 'Rebecca Leigh Spencer'},
#      'position': {'id': 1, 'name': 'Goalkeeper'},
#      'teammate': False},
#     {'location': [101.5, 31.8],
#      'player': {'id': 15623, 'name': 'Vivianne Miedema'},
#      'position': {'id': 23, 'name': 'Center Forward'},
#      'teammate': True},
#     {'location': [107.1, 19.8],
#      'player': {'id': 15620, 'name': 'Katie McCabe'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'teammate': True},
#     {'location': [113.4, 16.6],
#      'player': {'id': 10650, 'name': 'Jill Roord'},
#      'position': {'id': 15, 'name': 'Left Center Midfield'},
#      'teammate': True},
#     {'location': [96.8, 47.0],
#      'player': {'id': 10404, 'name': 'Noelle Maritz'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'teammate': True},
#     {'location': [106.1, 53.5],
#      'player': {'id': 11338, 'name': 'Caitlin Jade Foord'},
#      'position': {'id': 17, 'name': 'Right Wing'},
#      'teammate': True}]}},
#  {'id': '4c647337-a5bb-4333-bcd0-25ff38ff8aad',
#   'index': 484,
#   'period': 1,
#   'timestamp': '00:10:52.116',
#   'minute': 10,
#   'second': 52,
#   'type': {'id': 16, 'name': 'Shot'},
#   'possession': 23,
#   'possession_team': {'id': 968, 'name': 'Arsenal WFC'},
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'team': {'id': 968, 'name': 'Arsenal WFC'},
#   'player': {'id': 15623, 'name': 'Vivianne Miedema'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'location': [103.1, 40.2],
#   'duration': 0.099196,
#   'related_events': ['7265bc28-fa31-45f5-b2ef-4907b858235f',
#    'b299f7e2-95a2-4fa9-825b-f6465ea2baa0'],
#   'shot': {'statsbomb_xg': 0.07211444,
#    'end_location': [106.5, 41.0],
#    'key_pass_id': '2e569c59-fbb1-4d6e-88b5-22662b127bde',
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'type': {'id': 87, 'name': 'Open Play'},
#    'technique': {'id': 93, 'name': 'Normal'},
#    'outcome': {'id': 96, 'name': 'Blocked'},
#    'freeze_frame': [{'location': [100.5, 24.4],
#      'player': {'id': 15721, 'name': 'Gemma Suzanne Davison'},
#      'position': {'id': 12, 'name': 'Right Midfield'},
#      'teammate': False},
#     {'location': [105.8, 34.8],
#      'player': {'id': 5078, 'name': 'Alanna Stephanie Kennedy'},
#      'position': {'id': 9, 'name': 'Right Defensive Midfield'},
#      'teammate': False},
#     {'location': [109.0, 34.1],
#      'player': {'id': 53440, 'name': 'Esther Morgan'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'teammate': False},
#     {'location': [109.1, 40.5],
#      'player': {'id': 4648, 'name': 'Abbie McManus'},
#      'position': {'id': 3, 'name': 'Right Center Back'},
#      'teammate': False},
#     {'location': [106.3, 41.1],
#      'player': {'id': 5074, 'name': 'Shelina Laura Zadorsky'},
#      'position': {'id': 5, 'name': 'Left Center Back'},
#      'teammate': False},
#     {'location': [108.2, 43.6],
#      'player': {'id': 15572, 'name': 'Siri Worm'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'teammate': False},
#     {'location': [104.5, 40.0],
#      'player': {'id': 4865, 'name': 'Josie Green'},
#      'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#      'teammate': False},
#     {'location': [116.3, 40.3],
#      'player': {'id': 18158, 'name': 'Rebecca Leigh Spencer'},
#      'position': {'id': 1, 'name': 'Goalkeeper'},
#      'teammate': False},
#     {'location': [102.1, 32.4],
#      'player': {'id': 10192, 'name': 'Jordan Nobbs'},
#      'position': {'id': 21, 'name': 'Left Wing'},
#      'teammate': True},
#     {'location': [102.0, 31.6],
#      'player': {'id': 10650, 'name': 'Jill Roord'},
#      'position': {'id': 15, 'name': 'Left Center Midfield'},
#      'teammate': True},
#     {'location': [108.2, 33.5],
#      'player': {'id': 11338, 'name': 'Caitlin Jade Foord'},
#      'position': {'id': 17, 'name': 'Right Wing'},
#      'teammate': True},
#     {'location': [108.4, 41.3],
#      'player': {'id': 10658, 'name': 'Danielle van de Donk'},
#      'position': {'id': 13, 'name': 'Right Center Midfield'},
#      'teammate': True},
#     {'location': [97.9, 22.9],
#      'player': {'id': 15620, 'name': 'Katie McCabe'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'teammate': True},
#     {'location': [102.4, 54.2],
#      'player': {'id': 10404, 'name': 'Noelle Maritz'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'teammate': True},
#     {'location': [85.6, 59.1],
#      'player': {'id': 21048, 'name': 'Rosella Ayane'},
#      'position': {'id': 16, 'name': 'Left Midfield'},
#      'teammate': False}]}},
#  {'id': '2edff330-496a-46f8-a8b6-b3cc8cd54738',
#   'index': 595,
#   'period': 1,
#   'timestamp': '00:14:24.560',
#   'minute': 14,
#   'second': 24,
#   'type': {'id': 16, 'name': 'Shot'},
#   'possession': 30,
#   'possession_team': {'id': 968, 'name': 'Arsenal WFC'},
#   'play_pattern': {'id': 2, 'name': 'From Corner'},
#   'team': {'id': 968, 'name': 'Arsenal WFC'},
#   'player': {'id': 49697, 'name': 'Carlotte Wubben-Moy'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'location': [106.6, 35.7],
#   'duration': 0.181116,
#   'under_pressure': True,
#   'related_events': ['9ad22db0-2109-4192-9cb5-9f47bbcd1df7',
#    '9b038933-e4a1-45eb-bf17-9225bc553ca8',
#    'e7452c05-b755-49c3-b8e4-31915b44e4f7'],
#   'shot': {'statsbomb_xg': 0.042276483,
#    'end_location': [107.7, 36.0],
#    'key_pass_id': 'c3fe438a-b772-43f5-9471-e4b70731f28b',
#    'type': {'id': 87, 'name': 'Open Play'},
#    'outcome': {'id': 96, 'name': 'Blocked'},
#    'technique': {'id': 89, 'name': 'Backheel'},
#    'first_time': True,
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'freeze_frame': [{'location': [116.4, 5.3],
#      'player': {'id': 15620, 'name': 'Katie McCabe'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'teammate': True},
#     {'location': [97.3, 31.8],
#      'player': {'id': 15616, 'name': 'Kim Little'},
#      'position': {'id': 10, 'name': 'Center Defensive Midfield'},
#      'teammate': True},
#     {'location': [108.1, 36.0],
#      'player': {'id': 15721, 'name': 'Gemma Suzanne Davison'},
#      'position': {'id': 12, 'name': 'Right Midfield'},
#      'teammate': False},
#     {'location': [105.0, 41.5],
#      'player': {'id': 10658, 'name': 'Danielle van de Donk'},
#      'position': {'id': 13, 'name': 'Right Center Midfield'},
#      'teammate': True},
#     {'location': [103.8, 44.2],
#      'player': {'id': 11338, 'name': 'Caitlin Jade Foord'},
#      'position': {'id': 17, 'name': 'Right Wing'},
#      'teammate': True},
#     {'location': [104.1, 48.4],
#      'player': {'id': 15623, 'name': 'Vivianne Miedema'},
#      'position': {'id': 23, 'name': 'Center Forward'},
#      'teammate': True},
#     {'location': [99.8, 54.2],
#      'player': {'id': 10192, 'name': 'Jordan Nobbs'},
#      'position': {'id': 21, 'name': 'Left Wing'},
#      'teammate': True},
#     {'location': [113.8, 41.4],
#      'player': {'id': 10650, 'name': 'Jill Roord'},
#      'position': {'id': 15, 'name': 'Left Center Midfield'},
#      'teammate': True},
#     {'location': [118.1, 39.5],
#      'player': {'id': 18158, 'name': 'Rebecca Leigh Spencer'},
#      'position': {'id': 1, 'name': 'Goalkeeper'},
#      'teammate': False},
#     {'location': [105.9, 42.6],
#      'player': {'id': 15572, 'name': 'Siri Worm'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'teammate': False},
#     {'location': [106.5, 43.9],
#      'player': {'id': 31551, 'name': 'Kit Graham'},
#      'position': {'id': 24, 'name': 'Left Center Forward'},
#      'teammate': False},
#     {'location': [113.6, 37.4],
#      'player': {'id': 4648, 'name': 'Abbie McManus'},
#      'position': {'id': 3, 'name': 'Right Center Back'},
#      'teammate': False},
#     {'location': [114.3, 40.4],
#      'player': {'id': 5074, 'name': 'Shelina Laura Zadorsky'},
#      'position': {'id': 5, 'name': 'Left Center Back'},
#      'teammate': False},
#     {'location': [119.1, 36.6],
#      'player': {'id': 53440, 'name': 'Esther Morgan'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'teammate': False},
#     {'location': [113.0, 44.7],
#      'player': {'id': 5078, 'name': 'Alanna Stephanie Kennedy'},
#      'position': {'id': 9, 'name': 'Right Defensive Midfield'},
#      'teammate': False},
#     {'location': [101.2, 34.6],
#      'player': {'id': 31702, 'name': 'Rianna Dean'},
#      'position': {'id': 22, 'name': 'Right Center Forward'},
#      'teammate': False},
#     {'location': [106.2, 47.9],
#      'player': {'id': 4865, 'name': 'Josie Green'},
#      'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#      'teammate': False}]}},
#  {'id': '36a46259-ceb7-4878-801b-0a21a32a98a9',
#   'index': 711,
#   'period': 1,
#   'timestamp': '00:16:37.657',
#   'minute': 16,
#   'second': 37,
#   'type': {'id': 16, 'name': 'Shot'},
#   'possession': 34,
#   'possession_team': {'id': 968, 'name': 'Arsenal WFC'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 968, 'name': 'Arsenal WFC'},
#   'player': {'id': 15623, 'name': 'Vivianne Miedema'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'location': [111.8, 52.9],
#   'duration': 0.020196,
#   'related_events': ['01a57b35-ec70-4bc3-85c3-5d74fa224490',
#    '953f980c-7266-4a52-8df8-4293dd217472'],
#   'shot': {'statsbomb_xg': 0.08344615,
#    'end_location': [112.9, 50.2],
#    'key_pass_id': 'a55d952b-c7d6-4dca-8df7-1a876d4acbdf',
#    'technique': {'id': 93, 'name': 'Normal'},
#    'outcome': {'id': 96, 'name': 'Blocked'},
#    'type': {'id': 87, 'name': 'Open Play'},
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'freeze_frame': [{'location': [111.6, 35.6],
#      'player': {'id': 15721, 'name': 'Gemma Suzanne Davison'},
#      'position': {'id': 12, 'name': 'Right Midfield'},
#      'teammate': False},
#     {'location': [110.2, 39.2],
#      'player': {'id': 5078, 'name': 'Alanna Stephanie Kennedy'},
#      'position': {'id': 9, 'name': 'Right Defensive Midfield'},
#      'teammate': False},
#     {'location': [113.2, 41.6],
#      'player': {'id': 4648, 'name': 'Abbie McManus'},
#      'position': {'id': 3, 'name': 'Right Center Back'},
#      'teammate': False},
#     {'location': [106.8, 44.3],
#      'player': {'id': 53440, 'name': 'Esther Morgan'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'teammate': False},
#     {'location': [102.3, 66.4],
#      'player': {'id': 10650, 'name': 'Jill Roord'},
#      'position': {'id': 15, 'name': 'Left Center Midfield'},
#      'teammate': True},
#     {'location': [95.1, 62.8],
#      'player': {'id': 10404, 'name': 'Noelle Maritz'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'teammate': True},
#     {'location': [92.7, 50.8],
#      'player': {'id': 10192, 'name': 'Jordan Nobbs'},
#      'position': {'id': 21, 'name': 'Left Wing'},
#      'teammate': True},
#     {'location': [95.9, 38.5],
#      'player': {'id': 10658, 'name': 'Danielle van de Donk'},
#      'position': {'id': 13, 'name': 'Right Center Midfield'},
#      'teammate': True},
#     {'location': [113.0, 37.4],
#      'player': {'id': 11338, 'name': 'Caitlin Jade Foord'},
#      'position': {'id': 17, 'name': 'Right Wing'},
#      'teammate': True},
#     {'location': [112.4, 34.2],
#      'player': {'id': 15620, 'name': 'Katie McCabe'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'teammate': True},
#     {'location': [117.0, 43.7],
#      'player': {'id': 18158, 'name': 'Rebecca Leigh Spencer'},
#      'position': {'id': 1, 'name': 'Goalkeeper'},
#      'teammate': False},
#     {'location': [102.4, 53.6],
#      'player': {'id': 4865, 'name': 'Josie Green'},
#      'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#      'teammate': False},
#     {'location': [91.5, 57.0],
#      'player': {'id': 21048, 'name': 'Rosella Ayane'},
#      'position': {'id': 16, 'name': 'Left Midfield'},
#      'teammate': False},
#     {'location': [85.0, 45.6],
#      'player': {'id': 31551, 'name': 'Kit Graham'},
#      'position': {'id': 24, 'name': 'Left Center Forward'},
#      'teammate': False},
#     {'location': [99.7, 52.9],
#      'player': {'id': 15572, 'name': 'Siri Worm'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'teammate': False},
#     {'location': [112.8, 50.1],
#      'player': {'id': 5074, 'name': 'Shelina Laura Zadorsky'},
#      'position': {'id': 5, 'name': 'Left Center Back'},
#      'teammate': False}]}},
#  {'id': '36dc69c5-4b2a-4f3c-98b6-d656ec7ed7ae',
#   'index': 757,
#   'period': 1,
#   'timestamp': '00:18:04.336',
#   'minute': 18,
#   'second': 4,
#   'type': {'id': 16, 'name': 'Shot'},
#   'possession': 35,
#   'possession_team': {'id': 968, 'name': 'Arsenal WFC'},
#   'play_pattern': {'id': 2, 'name': 'From Corner'},
#   'team': {'id': 968, 'name': 'Arsenal WFC'},
#   'player': {'id': 10658, 'name': 'Danielle van de Donk'},
#   'position': {'id': 13, 'name': 'Right Center Midfield'},
#   'location': [105.0, 27.6],
#   'duration': 0.871175,
#   'related_events': ['07866133-6dd8-4f6c-8235-59e445acfbf9'],
#   'shot': {'statsbomb_xg': 0.04884978,
#    'end_location': [118.0, 36.7, 0.5],
#    'key_pass_id': 'f8f375af-e90a-490b-8f8a-f8d11230f6a6',
#    'technique': {'id': 93, 'name': 'Normal'},
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'outcome': {'id': 100, 'name': 'Saved'},
#    'type': {'id': 87, 'name': 'Open Play'},
#    'freeze_frame': [{'location': [117.7, 37.7],
#      'player': {'id': 18158, 'name': 'Rebecca Leigh Spencer'},
#      'position': {'id': 1, 'name': 'Goalkeeper'},
#      'teammate': False},
#     {'location': [103.0, 39.6],
#      'player': {'id': 15623, 'name': 'Vivianne Miedema'},
#      'position': {'id': 23, 'name': 'Center Forward'},
#      'teammate': True},
#     {'location': [113.4, 34.0],
#      'player': {'id': 11338, 'name': 'Caitlin Jade Foord'},
#      'position': {'id': 17, 'name': 'Right Wing'},
#      'teammate': True},
#     {'location': [112.8, 38.4],
#      'player': {'id': 10650, 'name': 'Jill Roord'},
#      'position': {'id': 15, 'name': 'Left Center Midfield'},
#      'teammate': True},
#     {'location': [103.5, 52.1],
#      'player': {'id': 15620, 'name': 'Katie McCabe'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'teammate': True},
#     {'location': [96.9, 29.2],
#      'player': {'id': 10192, 'name': 'Jordan Nobbs'},
#      'position': {'id': 21, 'name': 'Left Wing'},
#      'teammate': True},
#     {'location': [85.5, 42.4],
#      'player': {'id': 15616, 'name': 'Kim Little'},
#      'position': {'id': 10, 'name': 'Center Defensive Midfield'},
#      'teammate': True},
#     {'location': [100.5, 29.2],
#      'player': {'id': 4865, 'name': 'Josie Green'},
#      'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#      'teammate': False},
#     {'location': [92.0, 51.3],
#      'player': {'id': 15721, 'name': 'Gemma Suzanne Davison'},
#      'position': {'id': 12, 'name': 'Right Midfield'},
#      'teammate': False},
#     {'location': [106.8, 28.5],
#      'player': {'id': 31551, 'name': 'Kit Graham'},
#      'position': {'id': 24, 'name': 'Left Center Forward'},
#      'teammate': False},
#     {'location': [108.5, 28.0],
#      'player': {'id': 53440, 'name': 'Esther Morgan'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'teammate': False},
#     {'location': [108.0, 31.1],
#      'player': {'id': 5078, 'name': 'Alanna Stephanie Kennedy'},
#      'position': {'id': 9, 'name': 'Right Defensive Midfield'},
#      'teammate': False},
#     {'location': [113.7, 34.9],
#      'player': {'id': 4648, 'name': 'Abbie McManus'},
#      'position': {'id': 3, 'name': 'Right Center Back'},
#      'teammate': False},
#     {'location': [111.2, 39.0],
#      'player': {'id': 5074, 'name': 'Shelina Laura Zadorsky'},
#      'position': {'id': 5, 'name': 'Left Center Back'},
#      'teammate': False},
#     {'location': [109.8, 46.3],
#      'player': {'id': 15572, 'name': 'Siri Worm'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'teammate': False}]}},
#  {'id': '576b563e-db3e-492b-ab54-8703485c8dd2',
#   'index': 841,
#   'period': 1,
#   'timestamp': '00:21:46.319',
#   'minute': 21,
#   'second': 46,
#   'type': {'id': 16, 'name': 'Shot'},
#   'possession': 41,
#   'possession_team': {'id': 968, 'name': 'Arsenal WFC'},
#   'play_pattern': {'id': 3, 'name': 'From Free Kick'},
#   'team': {'id': 968, 'name': 'Arsenal WFC'},
#   'player': {'id': 49697, 'name': 'Carlotte Wubben-Moy'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'location': [109.2, 46.7],
#   'duration': 0.956559,
#   'under_pressure': True,
#   'related_events': ['34cc1cfe-1348-42b3-a70b-5ee24a0d791b',
#    'c5ea3eff-b488-406b-bb9b-695cbcd84b05'],
#   'shot': {'statsbomb_xg': 0.06421451,
#    'end_location': [120.0, 50.7, 0.5],
#    'key_pass_id': '38265e2b-8d36-4115-9ce6-baaf5585ece6',
#    'aerial_won': True,
#    'technique': {'id': 93, 'name': 'Normal'},
#    'outcome': {'id': 98, 'name': 'Off T'},
#    'type': {'id': 87, 'name': 'Open Play'},
#    'body_part': {'id': 37, 'name': 'Head'},
#    'freeze_frame': [{'location': [111.0, 40.8],
#      'player': {'id': 4648, 'name': 'Abbie McManus'},
#      'position': {'id': 3, 'name': 'Right Center Back'},
#      'teammate': False},
#     {'location': [107.9, 43.1],
#      'player': {'id': 5074, 'name': 'Shelina Laura Zadorsky'},
#      'position': {'id': 5, 'name': 'Left Center Back'},
#      'teammate': False},
#     {'location': [105.8, 41.0],
#      'player': {'id': 5078, 'name': 'Alanna Stephanie Kennedy'},
#      'position': {'id': 9, 'name': 'Right Defensive Midfield'},
#      'teammate': False},
#     {'location': [108.4, 36.0],
#      'player': {'id': 53440, 'name': 'Esther Morgan'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'teammate': False},
#     {'location': [97.1, 44.3],
#      'player': {'id': 31551, 'name': 'Kit Graham'},
#      'position': {'id': 24, 'name': 'Left Center Forward'},
#      'teammate': False},
#     {'location': [99.1, 26.3],
#      'player': {'id': 21048, 'name': 'Rosella Ayane'},
#      'position': {'id': 16, 'name': 'Left Midfield'},
#      'teammate': False},
#     {'location': [101.6, 27.4],
#      'player': {'id': 15616, 'name': 'Kim Little'},
#      'position': {'id': 10, 'name': 'Center Defensive Midfield'},
#      'teammate': True},
#     {'location': [108.7, 39.0],
#      'player': {'id': 11338, 'name': 'Caitlin Jade Foord'},
#      'position': {'id': 17, 'name': 'Right Wing'},
#      'teammate': True},
#     {'location': [100.1, 39.9],
#      'player': {'id': 15623, 'name': 'Vivianne Miedema'},
#      'position': {'id': 23, 'name': 'Center Forward'},
#      'teammate': True},
#     {'location': [96.6, 46.9],
#      'player': {'id': 10658, 'name': 'Danielle van de Donk'},
#      'position': {'id': 13, 'name': 'Right Center Midfield'},
#      'teammate': True},
#     {'location': [108.9, 51.9],
#      'player': {'id': 10650, 'name': 'Jill Roord'},
#      'position': {'id': 15, 'name': 'Left Center Midfield'},
#      'teammate': True},
#     {'location': [113.5, 45.1],
#      'player': {'id': 18158, 'name': 'Rebecca Leigh Spencer'},
#      'position': {'id': 1, 'name': 'Goalkeeper'},
#      'teammate': False},
#     {'location': [109.1, 49.9],
#      'player': {'id': 4865, 'name': 'Josie Green'},
#      'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#      'teammate': False},
#     {'location': [109.7, 46.0],
#      'player': {'id': 15572, 'name': 'Siri Worm'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'teammate': False}]}},
#  {'id': 'f41c00c0-ec17-4aac-883f-5f44e45649e7',
#   'index': 857,
#   'period': 1,
#   'timestamp': '00:22:35.345',
#   'minute': 22,
#   'second': 35,
#   'type': {'id': 16, 'name': 'Shot'},
#   'possession': 43,
#   'possession_team': {'id': 749, 'name': 'Tottenham Hotspur Women'},
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'team': {'id': 749, 'name': 'Tottenham Hotspur Women'},
#   'player': {'id': 31702, 'name': 'Rianna Dean'},
#   'position': {'id': 22, 'name': 'Right Center Forward'},
#   'location': [108.1, 56.8],
#   'duration': 0.141623,
#   'related_events': ['872c3751-ceb0-476c-8a2a-679a45358cb4',
#    '9d1c45f6-bf77-43b1-9862-1eb1ff6d4468'],
#   'shot': {'statsbomb_xg': 0.025647676,
#    'end_location': [109.7, 54.7],
#    'key_pass_id': 'a1c3f175-2def-4d54-9f4d-fb3dabbf75a6',
#    'technique': {'id': 93, 'name': 'Normal'},
#    'outcome': {'id': 96, 'name': 'Blocked'},
#    'type': {'id': 87, 'name': 'Open Play'},
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'freeze_frame': [{'location': [109.6, 54.6],
#      'player': {'id': 49697, 'name': 'Carlotte Wubben-Moy'},
#      'position': {'id': 3, 'name': 'Right Center Back'},
#      'teammate': False},
#     {'location': [106.2, 50.7],
#      'player': {'id': 10405, 'name': 'Lia Wälti'},
#      'position': {'id': 5, 'name': 'Left Center Back'},
#      'teammate': False},
#     {'location': [105.5, 39.0],
#      'player': {'id': 10404, 'name': 'Noelle Maritz'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'teammate': False},
#     {'location': [117.6, 43.2],
#      'player': {'id': 10237, 'name': 'Manuela Zinsberger'},
#      'position': {'id': 1, 'name': 'Goalkeeper'},
#      'teammate': False},
#     {'location': [102.1, 54.4],
#      'player': {'id': 10658, 'name': 'Danielle van de Donk'},
#      'position': {'id': 13, 'name': 'Right Center Midfield'},
#      'teammate': False},
#     {'location': [98.5, 62.8],
#      'player': {'id': 15620, 'name': 'Katie McCabe'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'teammate': False},
#     {'location': [99.2, 33.6],
#      'player': {'id': 21048, 'name': 'Rosella Ayane'},
#      'position': {'id': 16, 'name': 'Left Midfield'},
#      'teammate': True},
#     {'location': [100.3, 57.5],
#      'player': {'id': 31551, 'name': 'Kit Graham'},
#      'position': {'id': 24, 'name': 'Left Center Forward'},
#      'teammate': True}]}},
#  {'id': '5471ceb9-f094-4b89-98d4-810a76a85af3',
#   'index': 961,
#   'period': 1,
#   'timestamp': '00:25:24.354',
#   'minute': 25,
#   'second': 24,
#   'type': {'id': 16, 'name': 'Shot'},
#   'possession': 48,
#   'possession_team': {'id': 968, 'name': 'Arsenal WFC'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 968, 'name': 'Arsenal WFC'},
#   'player': {'id': 11338, 'name': 'Caitlin Jade Foord'},
#   'position': {'id': 17, 'name': 'Right Wing'},
#   'location': [109.2, 48.1],
#   'duration': 0.732364,
#   'related_events': ['f87d952b-6e57-4005-9317-e0bbe31c489a'],
#   'shot': {'statsbomb_xg': 0.1480437,
#    'end_location': [120.0, 37.2, 0.2],
#    'key_pass_id': '8e1a5ce1-e117-4517-b6a2-6e7a2fce3404',
#    'technique': {'id': 93, 'name': 'Normal'},
#    'first_time': True,
#    'outcome': {'id': 97, 'name': 'Goal'},
#    'type': {'id': 87, 'name': 'Open Play'},
#    'body_part': {'id': 38, 'name': 'Left Foot'},
#    'freeze_frame': [{'location': [109.0, 43.2],
#      'player': {'id': 15623, 'name': 'Vivianne Miedema'},
#      'position': {'id': 23, 'name': 'Center Forward'},
#      'teammate': True},
#     {'location': [109.4, 32.5],
#      'player': {'id': 10658, 'name': 'Danielle van de Donk'},
#      'position': {'id': 13, 'name': 'Right Center Midfield'},
#      'teammate': True},
#     {'location': [96.6, 47.9],
#      'player': {'id': 10192, 'name': 'Jordan Nobbs'},
#      'position': {'id': 21, 'name': 'Left Wing'},
#      'teammate': True},
#     {'location': [101.3, 39.2],
#      'player': {'id': 10650, 'name': 'Jill Roord'},
#      'position': {'id': 15, 'name': 'Left Center Midfield'},
#      'teammate': True},
#     {'location': [88.6, 28.6],
#      'player': {'id': 15620, 'name': 'Katie McCabe'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'teammate': True},
#     {'location': [118.6, 59.2],
#      'player': {'id': 10404, 'name': 'Noelle Maritz'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'teammate': True},
#     {'location': [117.7, 43.2],
#      'player': {'id': 18158, 'name': 'Rebecca Leigh Spencer'},
#      'position': {'id': 1, 'name': 'Goalkeeper'},
#      'teammate': False},
#     {'location': [87.4, 47.0],
#      'player': {'id': 31551, 'name': 'Kit Graham'},
#      'position': {'id': 24, 'name': 'Left Center Forward'},
#      'teammate': False},
#     {'location': [95.1, 29.6],
#      'player': {'id': 15721, 'name': 'Gemma Suzanne Davison'},
#      'position': {'id': 12, 'name': 'Right Midfield'},
#      'teammate': False},
#     {'location': [102.4, 48.2],
#      'player': {'id': 4865, 'name': 'Josie Green'},
#      'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#      'teammate': False},
#     {'location': [106.8, 41.6],
#      'player': {'id': 5078, 'name': 'Alanna Stephanie Kennedy'},
#      'position': {'id': 9, 'name': 'Right Defensive Midfield'},
#      'teammate': False},
#     {'location': [113.7, 37.2],
#      'player': {'id': 53440, 'name': 'Esther Morgan'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'teammate': False},
#     {'location': [113.0, 44.5],
#      'player': {'id': 4648, 'name': 'Abbie McManus'},
#      'position': {'id': 3, 'name': 'Right Center Back'},
#      'teammate': False},
#     {'location': [115.1, 49.4],
#      'player': {'id': 5074, 'name': 'Shelina Laura Zadorsky'},
#      'position': {'id': 5, 'name': 'Left Center Back'},
#      'teammate': False},
#     {'location': [106.8, 59.8],
#      'player': {'id': 21048, 'name': 'Rosella Ayane'},
#      'position': {'id': 16, 'name': 'Left Midfield'},
#      'teammate': False},
#     {'location': [111.4, 56.3],
#      'player': {'id': 15572, 'name': 'Siri Worm'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'teammate': False},
#     {'location': [82.6, 43.1],
#      'player': {'id': 15616, 'name': 'Kim Little'},
#      'position': {'id': 10, 'name': 'Center Defensive Midfield'},
#      'teammate': True}]}},
#  {'id': 'a064f1b3-41c0-4a87-b50e-c63db2713a3f',
#   'index': 1011,
#   'period': 1,
#   'timestamp': '00:26:52.636',
#   'minute': 26,
#   'second': 52,
#   'type': {'id': 16, 'name': 'Shot'},
#   'possession': 50,
#   'possession_team': {'id': 968, 'name': 'Arsenal WFC'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 968, 'name': 'Arsenal WFC'},
#   'player': {'id': 15623, 'name': 'Vivianne Miedema'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'location': [106.6, 46.9],
#   'duration': 0.111815,
#   'related_events': ['30a326de-de4f-495e-a3b2-624a69cca81b',
#    '56af3971-0726-4e2f-8ac7-3a3150dddc5b'],
#   'shot': {'statsbomb_xg': 0.19001487,
#    'end_location': [107.5, 46.6],
#    'key_pass_id': 'd4766e39-b64c-415d-8c11-372425a50a39',
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'type': {'id': 87, 'name': 'Open Play'},
#    'technique': {'id': 93, 'name': 'Normal'},
#    'first_time': True,
#    'outcome': {'id': 96, 'name': 'Blocked'},
#    'freeze_frame': [{'location': [110.9, 34.8],
#      'player': {'id': 10650, 'name': 'Jill Roord'},
#      'position': {'id': 15, 'name': 'Left Center Midfield'},
#      'teammate': True},
#     {'location': [104.2, 40.7],
#      'player': {'id': 10658, 'name': 'Danielle van de Donk'},
#      'position': {'id': 13, 'name': 'Right Center Midfield'},
#      'teammate': True},
#     {'location': [98.9, 48.7],
#      'player': {'id': 10404, 'name': 'Noelle Maritz'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'teammate': True},
#     {'location': [108.2, 46.4],
#      'player': {'id': 11338, 'name': 'Caitlin Jade Foord'},
#      'position': {'id': 17, 'name': 'Right Wing'},
#      'teammate': True},
#     {'location': [90.8, 29.7],
#      'player': {'id': 15721, 'name': 'Gemma Suzanne Davison'},
#      'position': {'id': 12, 'name': 'Right Midfield'},
#      'teammate': False},
#     {'location': [100.1, 37.5],
#      'player': {'id': 5078, 'name': 'Alanna Stephanie Kennedy'},
#      'position': {'id': 9, 'name': 'Right Defensive Midfield'},
#      'teammate': False},
#     {'location': [110.9, 24.1],
#      'player': {'id': 53440, 'name': 'Esther Morgan'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'teammate': False},
#     {'location': [106.0, 41.0],
#      'player': {'id': 4865, 'name': 'Josie Green'},
#      'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#      'teammate': False},
#     {'location': [100.1, 52.6],
#      'player': {'id': 21048, 'name': 'Rosella Ayane'},
#      'position': {'id': 16, 'name': 'Left Midfield'},
#      'teammate': False},
#     {'location': [111.1, 35.9],
#      'player': {'id': 4648, 'name': 'Abbie McManus'},
#      'position': {'id': 3, 'name': 'Right Center Back'},
#      'teammate': False},
#     {'location': [113.5, 40.2],
#      'player': {'id': 5074, 'name': 'Shelina Laura Zadorsky'},
#      'position': {'id': 5, 'name': 'Left Center Back'},
#      'teammate': False},
#     {'location': [108.8, 47.8],
#      'player': {'id': 15572, 'name': 'Siri Worm'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'teammate': False},
#     {'location': [117.7, 40.6],
#      'player': {'id': 18158, 'name': 'Rebecca Leigh Spencer'},
#      'position': {'id': 1, 'name': 'Goalkeeper'},
#      'teammate': False},
#     {'location': [94.1, 34.2],
#      'player': {'id': 10192, 'name': 'Jordan Nobbs'},
#      'position': {'id': 21, 'name': 'Left Wing'},
#      'teammate': True},
#     {'location': [111.6, 16.8],
#      'player': {'id': 15620, 'name': 'Katie McCabe'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'teammate': True}]}},
#  {'id': '2edc6086-43b3-4b3b-a140-1f2aada4e2aa',
#   'index': 1057,
#   'period': 1,
#   'timestamp': '00:27:28.387',
#   'minute': 27,
#   'second': 28,
#   'type': {'id': 16, 'name': 'Shot'},
#   'possession': 50,
#   'possession_team': {'id': 968, 'name': 'Arsenal WFC'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 968, 'name': 'Arsenal WFC'},
#   'player': {'id': 10192, 'name': 'Jordan Nobbs'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'location': [102.5, 36.6],
#   'duration': 1.010114,
#   'related_events': ['98c5dc55-1663-49c4-945d-572bdbfb385b'],
#   'shot': {'statsbomb_xg': 0.068256795,
#    'end_location': [116.6, 36.9, 2.0],
#    'key_pass_id': '0a748b15-31e6-48d0-ba83-a21fa4ee51ab',
#    'technique': {'id': 93, 'name': 'Normal'},
#    'outcome': {'id': 100, 'name': 'Saved'},
#    'type': {'id': 87, 'name': 'Open Play'},
#    'body_part': {'id': 38, 'name': 'Left Foot'},
#    'freeze_frame': [{'location': [111.5, 39.8],
#      'player': {'id': 10650, 'name': 'Jill Roord'},
#      'position': {'id': 15, 'name': 'Left Center Midfield'},
#      'teammate': True},
#     {'location': [110.2, 48.5],
#      'player': {'id': 15572, 'name': 'Siri Worm'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'teammate': False},
#     {'location': [92.4, 57.7],
#      'player': {'id': 21048, 'name': 'Rosella Ayane'},
#      'position': {'id': 16, 'name': 'Left Midfield'},
#      'teammate': False},
#     {'location': [116.9, 38.6],
#      'player': {'id': 18158, 'name': 'Rebecca Leigh Spencer'},
#      'position': {'id': 1, 'name': 'Goalkeeper'},
#      'teammate': False},
#     {'location': [105.8, 29.0],
#      'player': {'id': 15623, 'name': 'Vivianne Miedema'},
#      'position': {'id': 23, 'name': 'Center Forward'},
#      'teammate': True},
#     {'location': [99.4, 46.6],
#      'player': {'id': 10658, 'name': 'Danielle van de Donk'},
#      'position': {'id': 13, 'name': 'Right Center Midfield'},
#      'teammate': True},
#     {'location': [109.5, 49.3],
#      'player': {'id': 11338, 'name': 'Caitlin Jade Foord'},
#      'position': {'id': 17, 'name': 'Right Wing'},
#      'teammate': True},
#     {'location': [111.1, 40.0],
#      'player': {'id': 5074, 'name': 'Shelina Laura Zadorsky'},
#      'position': {'id': 5, 'name': 'Left Center Back'},
#      'teammate': False},
#     {'location': [110.5, 22.0],
#      'player': {'id': 15620, 'name': 'Katie McCabe'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'teammate': True},
#     {'location': [106.7, 55.2],
#      'player': {'id': 10404, 'name': 'Noelle Maritz'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'teammate': True},
#     {'location': [99.9, 28.9],
#      'player': {'id': 15721, 'name': 'Gemma Suzanne Davison'},
#      'position': {'id': 12, 'name': 'Right Midfield'},
#      'teammate': False},
#     {'location': [100.3, 37.8],
#      'player': {'id': 31551, 'name': 'Kit Graham'},
#      'position': {'id': 24, 'name': 'Left Center Forward'},
#      'teammate': False},
#     {'location': [105.9, 32.3],
#      'player': {'id': 5078, 'name': 'Alanna Stephanie Kennedy'},
#      'position': {'id': 9, 'name': 'Right Defensive Midfield'},
#      'teammate': False},
#     {'location': [109.1, 31.6],
#      'player': {'id': 53440, 'name': 'Esther Morgan'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'teammate': False},
#     {'location': [104.8, 40.5],
#      'player': {'id': 4865, 'name': 'Josie Green'},
#      'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#      'teammate': False},
#     {'location': [110.4, 36.1],
#      'player': {'id': 4648, 'name': 'Abbie McManus'},
#      'position': {'id': 3, 'name': 'Right Center Back'},
#      'teammate': False}]}},
#  {'id': '6af483eb-8b9c-4606-bdc8-532490d6f2e3',
#   'index': 1124,
#   'period': 1,
#   'timestamp': '00:30:33.216',
#   'minute': 30,
#   'second': 33,
#   'type': {'id': 16, 'name': 'Shot'},
#   'possession': 55,
#   'possession_team': {'id': 968, 'name': 'Arsenal WFC'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 968, 'name': 'Arsenal WFC'},
#   'player': {'id': 10192, 'name': 'Jordan Nobbs'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'location': [99.1, 25.2],
#   'duration': 1.39354,
#   'related_events': ['8dc0fd72-df8a-49e5-af65-823f1e4f7dd2'],
#   'shot': {'statsbomb_xg': 0.0313157,
#    'end_location': [120.0, 46.0, 5.6],
#    'key_pass_id': 'a2dfb5f1-80fd-4b43-86c5-1243647bf569',
#    'technique': {'id': 93, 'name': 'Normal'},
#    'outcome': {'id': 98, 'name': 'Off T'},
#    'type': {'id': 87, 'name': 'Open Play'},
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'freeze_frame': [{'location': [95.4, 53.3],
#      'player': {'id': 15721, 'name': 'Gemma Suzanne Davison'},
#      'position': {'id': 12, 'name': 'Right Midfield'},
#      'teammate': False},
#     {'location': [103.5, 36.0],
#      'player': {'id': 10650, 'name': 'Jill Roord'},
#      'position': {'id': 15, 'name': 'Left Center Midfield'},
#      'teammate': True},
#     {'location': [92.1, 50.8],
#      'player': {'id': 10404, 'name': 'Noelle Maritz'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'teammate': True},
#     {'location': [105.6, 40.0],
#      'player': {'id': 11338, 'name': 'Caitlin Jade Foord'},
#      'position': {'id': 17, 'name': 'Right Wing'},
#      'teammate': True},
#     {'location': [100.1, 46.6],
#      'player': {'id': 10658, 'name': 'Danielle van de Donk'},
#      'position': {'id': 13, 'name': 'Right Center Midfield'},
#      'teammate': True},
#     {'location': [104.3, 45.5],
#      'player': {'id': 15572, 'name': 'Siri Worm'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'teammate': False},
#     {'location': [79.5, 35.0],
#      'player': {'id': 21048, 'name': 'Rosella Ayane'},
#      'position': {'id': 16, 'name': 'Left Midfield'},
#      'teammate': False},
#     {'location': [104.8, 37.6],
#      'player': {'id': 5074, 'name': 'Shelina Laura Zadorsky'},
#      'position': {'id': 5, 'name': 'Left Center Back'},
#      'teammate': False},
#     {'location': [104.0, 36.1],
#      'player': {'id': 4865, 'name': 'Josie Green'},
#      'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#      'teammate': False},
#     {'location': [103.3, 35.2],
#      'player': {'id': 4648, 'name': 'Abbie McManus'},
#      'position': {'id': 3, 'name': 'Right Center Back'},
#      'teammate': False},
#     {'location': [97.3, 42.7],
#      'player': {'id': 31551, 'name': 'Kit Graham'},
#      'position': {'id': 24, 'name': 'Left Center Forward'},
#      'teammate': False},
#     {'location': [99.5, 38.2],
#      'player': {'id': 5078, 'name': 'Alanna Stephanie Kennedy'},
#      'position': {'id': 9, 'name': 'Right Defensive Midfield'},
#      'teammate': False},
#     {'location': [101.0, 28.0],
#      'player': {'id': 53440, 'name': 'Esther Morgan'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'teammate': False},
#     {'location': [117.6, 37.6],
#      'player': {'id': 18158, 'name': 'Rebecca Leigh Spencer'},
#      'position': {'id': 1, 'name': 'Goalkeeper'},
#      'teammate': False},
#     {'location': [103.7, 52.9],
#      'player': {'id': 15623, 'name': 'Vivianne Miedema'},
#      'position': {'id': 23, 'name': 'Center Forward'},
#      'teammate': True}]}},
#  {'id': '6c82b0cf-8e50-44a3-a7d4-44f497070960',
#   'index': 1208,
#   'period': 1,
#   'timestamp': '00:32:34.478',
#   'minute': 32,
#   'second': 34,
#   'type': {'id': 16, 'name': 'Shot'},
#   'possession': 59,
#   'possession_team': {'id': 968, 'name': 'Arsenal WFC'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 968, 'name': 'Arsenal WFC'},
#   'player': {'id': 10650, 'name': 'Jill Roord'},
#   'position': {'id': 15, 'name': 'Left Center Midfield'},
#   'location': [109.0, 39.2],
#   'duration': 0.159895,
#   'related_events': ['8d19fdf7-7767-40d5-ae3c-284644c1284a',
#    'b84aaf78-2394-4b18-9d8c-f5993d657172'],
#   'shot': {'statsbomb_xg': 0.06640703,
#    'end_location': [110.0, 39.2],
#    'key_pass_id': '9b378881-32c1-44f8-894a-f89591796d65',
#    'outcome': {'id': 96, 'name': 'Blocked'},
#    'type': {'id': 87, 'name': 'Open Play'},
#    'body_part': {'id': 38, 'name': 'Left Foot'},
#    'technique': {'id': 91, 'name': 'Half Volley'},
#    'first_time': True,
#    'freeze_frame': [{'location': [111.5, 17.4],
#      'player': {'id': 10192, 'name': 'Jordan Nobbs'},
#      'position': {'id': 21, 'name': 'Left Wing'},
#      'teammate': True},
#     {'location': [85.3, 32.4],
#      'player': {'id': 15620, 'name': 'Katie McCabe'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'teammate': True},
#     {'location': [102.2, 67.1],
#      'player': {'id': 15721, 'name': 'Gemma Suzanne Davison'},
#      'position': {'id': 12, 'name': 'Right Midfield'},
#      'teammate': False},
#     {'location': [81.6, 43.9],
#      'player': {'id': 15616, 'name': 'Kim Little'},
#      'position': {'id': 10, 'name': 'Center Defensive Midfield'},
#      'teammate': True},
#     {'location': [105.6, 51.2],
#      'player': {'id': 10404, 'name': 'Noelle Maritz'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'teammate': True},
#     {'location': [98.5, 65.2],
#      'player': {'id': 11338, 'name': 'Caitlin Jade Foord'},
#      'position': {'id': 17, 'name': 'Right Wing'},
#      'teammate': True},
#     {'location': [117.3, 39.2],
#      'player': {'id': 18158, 'name': 'Rebecca Leigh Spencer'},
#      'position': {'id': 1, 'name': 'Goalkeeper'},
#      'teammate': False},
#     {'location': [108.6, 40.4],
#      'player': {'id': 4865, 'name': 'Josie Green'},
#      'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#      'teammate': False},
#     {'location': [114.1, 30.2],
#      'player': {'id': 53440, 'name': 'Esther Morgan'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'teammate': False},
#     {'location': [110.7, 39.1],
#      'player': {'id': 5074, 'name': 'Shelina Laura Zadorsky'},
#      'position': {'id': 5, 'name': 'Left Center Back'},
#      'teammate': False},
#     {'location': [106.0, 37.3],
#      'player': {'id': 5078, 'name': 'Alanna Stephanie Kennedy'},
# ...
#      'position': {'id': 23, 'name': 'Center Forward'},
#      'teammate': False},
#     {'location': [95.8, 37.1],
#      'player': {'id': 10658, 'name': 'Danielle van de Donk'},
#      'position': {'id': 13, 'name': 'Right Center Midfield'},
#      'teammate': False},
#     {'location': [97.9, 47.0],
#      'player': {'id': 45156, 'name': 'Malin Gut'},
#      'position': {'id': 17, 'name': 'Right Wing'},
#      'teammate': False},
#     {'location': [102.4, 47.3],
#      'player': {'id': 10380, 'name': 'Leonie Maier'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'teammate': False},
#     {'location': [106.1, 46.3],
#      'player': {'id': 49697, 'name': 'Carlotte Wubben-Moy'},
#      'position': {'id': 3, 'name': 'Right Center Back'},
#      'teammate': False},
#     {'location': [107.9, 49.8],
#      'player': {'id': 10405, 'name': 'Lia Wälti'},
#      'position': {'id': 5, 'name': 'Left Center Back'},
#      'teammate': False},
#     {'location': [118.3, 41.5],
#      'player': {'id': 10237, 'name': 'Manuela Zinsberger'},
#      'position': {'id': 1, 'name': 'Goalkeeper'},
#      'teammate': False},
#     {'location': [106.7, 41.6],
#      'player': {'id': 78072, 'name': 'Anna Patten'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'teammate': False},
#     {'location': [103.0, 49.4],
#      'player': {'id': 15616, 'name': 'Kim Little'},
#      'position': {'id': 10, 'name': 'Center Defensive Midfield'},
#      'teammate': False}]}},
#  {'id': '67095271-48ba-4624-86a0-83715c2e9398',
#   'index': 3443,
#   'period': 2,
#   'timestamp': '00:41:00.117',
#   'minute': 86,
#   'second': 0,
#   'type': {'id': 16, 'name': 'Shot'},
#   'possession': 174,
#   'possession_team': {'id': 749, 'name': 'Tottenham Hotspur Women'},
#   'play_pattern': {'id': 7, 'name': 'From Goal Kick'},
#   'team': {'id': 749, 'name': 'Tottenham Hotspur Women'},
#   'player': {'id': 31563, 'name': 'Rachel Williams'},
#   'position': {'id': 24, 'name': 'Left Center Forward'},
#   'location': [111.4, 39.2],
#   'duration': 1.352004,
#   'related_events': ['b3c2a139-bb10-46c6-949b-6999e897fc51'],
#   'shot': {'statsbomb_xg': 0.13972665,
#    'end_location': [120.0, 47.2, 1.5],
#    'key_pass_id': '0e345d11-1dfc-4ea5-8616-8cc078992d38',
#    'technique': {'id': 93, 'name': 'Normal'},
#    'body_part': {'id': 37, 'name': 'Head'},
#    'outcome': {'id': 98, 'name': 'Off T'},
#    'type': {'id': 87, 'name': 'Open Play'},
#    'freeze_frame': [{'location': [110.7, 46.4],
#      'player': {'id': 31551, 'name': 'Kit Graham'},
#      'position': {'id': 22, 'name': 'Right Center Forward'},
#      'teammate': True},
#     {'location': [108.9, 32.7],
#      'player': {'id': 5074, 'name': 'Shelina Laura Zadorsky'},
#      'position': {'id': 5, 'name': 'Left Center Back'},
#      'teammate': True},
#     {'location': [113.2, 6.6],
#      'player': {'id': 31702, 'name': 'Rianna Dean'},
#      'position': {'id': 16, 'name': 'Left Midfield'},
#      'teammate': True},
#     {'location': [98.1, 39.1],
#      'player': {'id': 22798, 'name': 'So-Hyun Cho'},
#      'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#      'teammate': True},
#     {'location': [93.3, 20.0],
#      'player': {'id': 15572, 'name': 'Siri Worm'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'teammate': True},
#     {'location': [119.2, 39.4],
#      'player': {'id': 10237, 'name': 'Manuela Zinsberger'},
#      'position': {'id': 1, 'name': 'Goalkeeper'},
#      'teammate': False},
#     {'location': [111.9, 41.8],
#      'player': {'id': 10405, 'name': 'Lia Wälti'},
#      'position': {'id': 5, 'name': 'Left Center Back'},
#      'teammate': False},
#     {'location': [110.9, 42.5],
#      'player': {'id': 49697, 'name': 'Carlotte Wubben-Moy'},
#      'position': {'id': 3, 'name': 'Right Center Back'},
#      'teammate': False},
#     {'location': [113.5, 33.7],
#      'player': {'id': 78072, 'name': 'Anna Patten'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'teammate': False},
#     {'location': [107.4, 40.7],
#      'player': {'id': 15616, 'name': 'Kim Little'},
#      'position': {'id': 10, 'name': 'Center Defensive Midfield'},
#      'teammate': False},
#     {'location': [111.0, 38.5],
#      'player': {'id': 10658, 'name': 'Danielle van de Donk'},
#      'position': {'id': 13, 'name': 'Right Center Midfield'},
#      'teammate': False},
#     {'location': [104.5, 50.4],
#      'player': {'id': 10192, 'name': 'Jordan Nobbs'},
#      'position': {'id': 21, 'name': 'Left Wing'},
#      'teammate': False},
#     {'location': [96.9, 39.1],
#      'player': {'id': 10650, 'name': 'Jill Roord'},
#      'position': {'id': 15, 'name': 'Left Center Midfield'},
#      'teammate': False},
#     {'location': [110.8, 15.1],
#      'player': {'id': 10380, 'name': 'Leonie Maier'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'teammate': False},
#     {'location': [98.1, 21.0],
#      'player': {'id': 45156, 'name': 'Malin Gut'},
#      'position': {'id': 17, 'name': 'Right Wing'},
#      'teammate': False}]}},
#  {'id': '9b9b59bb-7dc0-45a6-9a79-266d8ab7232d',
#   'index': 3497,
#   'period': 2,
#   'timestamp': '00:42:37.549',
#   'minute': 87,
#   'second': 37,
#   'type': {'id': 16, 'name': 'Shot'},
#   'possession': 177,
#   'possession_team': {'id': 968, 'name': 'Arsenal WFC'},
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'team': {'id': 968, 'name': 'Arsenal WFC'},
#   'player': {'id': 10650, 'name': 'Jill Roord'},
#   'position': {'id': 15, 'name': 'Left Center Midfield'},
#   'location': [98.9, 42.1],
#   'duration': 0.889679,
#   'under_pressure': True,
#   'related_events': ['5e10884d-9749-411b-93cc-55835d4035d7',
#    '9b3b32fd-7017-4487-a858-57282dfe9513'],
#   'shot': {'statsbomb_xg': 0.049546566,
#    'end_location': [120.0, 45.6, 2.6],
#    'key_pass_id': '6d501c6b-6f8b-41af-949f-4427a0d0abb2',
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'technique': {'id': 93, 'name': 'Normal'},
#    'outcome': {'id': 98, 'name': 'Off T'},
#    'type': {'id': 87, 'name': 'Open Play'},
#    'freeze_frame': [{'location': [117.8, 40.9],
#      'player': {'id': 18158, 'name': 'Rebecca Leigh Spencer'},
#      'position': {'id': 1, 'name': 'Goalkeeper'},
#      'teammate': False},
#     {'location': [104.5, 25.5],
#      'player': {'id': 10192, 'name': 'Jordan Nobbs'},
#      'position': {'id': 21, 'name': 'Left Wing'},
#      'teammate': True},
#     {'location': [82.8, 24.2],
#      'player': {'id': 31550, 'name': 'Angela Addison'},
#      'position': {'id': 12, 'name': 'Right Midfield'},
#      'teammate': False},
#     {'location': [95.6, 49.7],
#      'player': {'id': 15564, 'name': 'Lucy Quinn'},
#      'position': {'id': 22, 'name': 'Right Center Forward'},
#      'teammate': False},
#     {'location': [91.6, 38.9],
#      'player': {'id': 31563, 'name': 'Rachel Williams'},
#      'position': {'id': 24, 'name': 'Left Center Forward'},
#      'teammate': False},
#     {'location': [79.9, 25.8],
#      'player': {'id': 10380, 'name': 'Leonie Maier'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'teammate': True},
#     {'location': [86.1, 42.8],
#      'player': {'id': 15616, 'name': 'Kim Little'},
#      'position': {'id': 10, 'name': 'Center Defensive Midfield'},
#      'teammate': True},
#     {'location': [98.2, 53.3],
#      'player': {'id': 45156, 'name': 'Malin Gut'},
#      'position': {'id': 17, 'name': 'Right Wing'},
#      'teammate': True},
#     {'location': [104.4, 60.9],
#      'player': {'id': 78072, 'name': 'Anna Patten'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'teammate': True},
#     {'location': [102.9, 47.8],
#      'player': {'id': 10658, 'name': 'Danielle van de Donk'},
#      'position': {'id': 13, 'name': 'Right Center Midfield'},
#      'teammate': True},
#     {'location': [102.6, 42.5],
#      'player': {'id': 4648, 'name': 'Abbie McManus'},
#      'position': {'id': 3, 'name': 'Right Center Back'},
#      'teammate': False},
#     {'location': [105.0, 51.4],
#      'player': {'id': 22798, 'name': 'So-Hyun Cho'},
#      'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#      'teammate': False},
#     {'location': [105.2, 46.9],
#      'player': {'id': 15572, 'name': 'Siri Worm'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'teammate': False},
#     {'location': [100.8, 45.2],
#      'player': {'id': 5078, 'name': 'Alanna Stephanie Kennedy'},
#      'position': {'id': 9, 'name': 'Right Defensive Midfield'},
#      'teammate': False},
#     {'location': [100.2, 41.2],
#      'player': {'id': 5074, 'name': 'Shelina Laura Zadorsky'},
#      'position': {'id': 5, 'name': 'Left Center Back'},
#      'teammate': False},
#     {'location': [105.4, 36.4],
#      'player': {'id': 15623, 'name': 'Vivianne Miedema'},
#      'position': {'id': 23, 'name': 'Center Forward'},
#      'teammate': True},
#     {'location': [104.9, 35.2],
#      'player': {'id': 53440, 'name': 'Esther Morgan'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'teammate': False}]}},
#  {'id': '1312e183-ade3-4675-b9a2-6fb076df80a0',
#   'index': 3589,
#   'period': 2,
#   'timestamp': '00:44:33.528',
#   'minute': 89,
#   'second': 33,
#   'type': {'id': 16, 'name': 'Shot'},
#   'possession': 179,
#   'possession_team': {'id': 968, 'name': 'Arsenal WFC'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 968, 'name': 'Arsenal WFC'},
#   'player': {'id': 15623, 'name': 'Vivianne Miedema'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'location': [98.6, 25.3],
#   'duration': 0.031926,
#   'related_events': ['49fc6780-8a2a-4409-be56-35dc3968cb37',
#    'baf91c27-8dde-4627-bcda-ec2b5db23ace'],
#   'shot': {'statsbomb_xg': 0.023606546,
#    'end_location': [100.5, 26.1],
#    'key_pass_id': 'c5c7afeb-8622-4bfa-b390-084a7ec16a59',
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'type': {'id': 87, 'name': 'Open Play'},
#    'outcome': {'id': 96, 'name': 'Blocked'},
#    'technique': {'id': 93, 'name': 'Normal'},
#    'freeze_frame': [{'location': [104.5, 24.5],
#      'player': {'id': 53440, 'name': 'Esther Morgan'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'teammate': False},
#     {'location': [108.1, 31.3],
#      'player': {'id': 4648, 'name': 'Abbie McManus'},
#      'position': {'id': 3, 'name': 'Right Center Back'},
#      'teammate': False},
#     {'location': [106.6, 34.9],
#      'player': {'id': 5074, 'name': 'Shelina Laura Zadorsky'},
#      'position': {'id': 5, 'name': 'Left Center Back'},
#      'teammate': False},
#     {'location': [104.5, 31.7],
#      'player': {'id': 5078, 'name': 'Alanna Stephanie Kennedy'},
#      'position': {'id': 9, 'name': 'Right Defensive Midfield'},
#      'teammate': False},
#     {'location': [100.6, 26.1],
#      'player': {'id': 31550, 'name': 'Angela Addison'},
#      'position': {'id': 12, 'name': 'Right Midfield'},
#      'teammate': False},
#     {'location': [108.5, 43.7],
#      'player': {'id': 15572, 'name': 'Siri Worm'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'teammate': False},
#     {'location': [102.2, 36.5],
#      'player': {'id': 22798, 'name': 'So-Hyun Cho'},
#      'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#      'teammate': False},
#     {'location': [86.6, 34.4],
#      'player': {'id': 31563, 'name': 'Rachel Williams'},
#      'position': {'id': 24, 'name': 'Left Center Forward'},
#      'teammate': False},
#     {'location': [105.5, 21.4],
#      'player': {'id': 10192, 'name': 'Jordan Nobbs'},
#      'position': {'id': 21, 'name': 'Left Wing'},
#      'teammate': True},
#     {'location': [104.9, 28.8],
#      'player': {'id': 10380, 'name': 'Leonie Maier'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'teammate': True},
#     {'location': [107.6, 36.7],
#      'player': {'id': 10650, 'name': 'Jill Roord'},
#      'position': {'id': 15, 'name': 'Left Center Midfield'},
#      'teammate': True},
#     {'location': [102.6, 34.3],
#      'player': {'id': 15616, 'name': 'Kim Little'},
#      'position': {'id': 10, 'name': 'Center Defensive Midfield'},
#      'teammate': True},
#     {'location': [108.0, 46.2],
#      'player': {'id': 10658, 'name': 'Danielle van de Donk'},
#      'position': {'id': 13, 'name': 'Right Center Midfield'},
#      'teammate': True},
#     {'location': [117.5, 37.7],
#      'player': {'id': 18158, 'name': 'Rebecca Leigh Spencer'},
#      'position': {'id': 1, 'name': 'Goalkeeper'},
#      'teammate': False}]}},
#  {'id': '09e61658-2ca3-4b47-bdec-a05a2c1baef6',
#   'index': 3717,
#   'period': 2,
#   'timestamp': '00:48:25.915',
#   'minute': 93,
#   'second': 25,
#   'type': {'id': 16, 'name': 'Shot'},
#   'possession': 189,
#   'possession_team': {'id': 749, 'name': 'Tottenham Hotspur Women'},
#   'play_pattern': {'id': 3, 'name': 'From Free Kick'},
#   'team': {'id': 749, 'name': 'Tottenham Hotspur Women'},
#   'player': {'id': 15572, 'name': 'Siri Worm'},
#   'position': {'id': 6, 'name': 'Left Back'},
#   'location': [95.9, 55.6],
#   'duration': 1.291031,
#   'related_events': ['1b2ee122-a623-4ae4-bf96-5a6540e4a2a4'],
#   'shot': {'statsbomb_xg': 0.03829121,
#    'end_location': [120.0, 33.2, 4.2],
#    'outcome': {'id': 98, 'name': 'Off T'},
#    'type': {'id': 62, 'name': 'Free Kick'},
#    'body_part': {'id': 38, 'name': 'Left Foot'},
#    'technique': {'id': 93, 'name': 'Normal'},
#    'freeze_frame': [{'location': [105.9, 32.7],
#      'player': {'id': 45156, 'name': 'Malin Gut'},
#      'position': {'id': 17, 'name': 'Right Wing'},
#      'teammate': False},
#     {'location': [104.7, 32.1],
#      'player': {'id': 15616, 'name': 'Kim Little'},
#      'position': {'id': 10, 'name': 'Center Defensive Midfield'},
#      'teammate': False},
#     {'location': [105.6, 35.1],
#      'player': {'id': 10405, 'name': 'Lia Wälti'},
#      'position': {'id': 5, 'name': 'Left Center Back'},
#      'teammate': False},
#     {'location': [103.6, 40.0],
#      'player': {'id': 10658, 'name': 'Danielle van de Donk'},
#      'position': {'id': 13, 'name': 'Right Center Midfield'},
#      'teammate': False},
#     {'location': [107.3, 38.2],
#      'player': {'id': 10380, 'name': 'Leonie Maier'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'teammate': False},
#     {'location': [105.0, 49.7],
#      'player': {'id': 10650, 'name': 'Jill Roord'},
#      'position': {'id': 15, 'name': 'Left Center Midfield'},
#      'teammate': False},
#     {'location': [105.2, 50.7],
#      'player': {'id': 78072, 'name': 'Anna Patten'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'teammate': False},
#     {'location': [105.0, 50.0],
#      'player': {'id': 15623, 'name': 'Vivianne Miedema'},
#      'position': {'id': 23, 'name': 'Center Forward'},
#      'teammate': False},
#     {'location': [104.6, 49.3],
#      'player': {'id': 49697, 'name': 'Carlotte Wubben-Moy'},
#      'position': {'id': 3, 'name': 'Right Center Back'},
#      'teammate': False},
#     {'location': [104.2, 47.1],
#      'player': {'id': 10192, 'name': 'Jordan Nobbs'},
#      'position': {'id': 21, 'name': 'Left Wing'},
#      'teammate': False},
#     {'location': [118.9, 39.7],
#      'player': {'id': 10237, 'name': 'Manuela Zinsberger'},
#      'position': {'id': 1, 'name': 'Goalkeeper'},
#      'teammate': False},
#     {'location': [104.1, 31.1],
#      'player': {'id': 22798, 'name': 'So-Hyun Cho'},
#      'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#      'teammate': True},
#     {'location': [105.1, 34.8],
#      'player': {'id': 15564, 'name': 'Lucy Quinn'},
#      'position': {'id': 22, 'name': 'Right Center Forward'},
#      'teammate': True},
#     {'location': [106.2, 30.8],
#      'player': {'id': 31563, 'name': 'Rachel Williams'},
#      'position': {'id': 24, 'name': 'Left Center Forward'},
#      'teammate': True},
#     {'location': [106.1, 39.6],
#      'player': {'id': 5074, 'name': 'Shelina Laura Zadorsky'},
#      'position': {'id': 5, 'name': 'Left Center Back'},
#      'teammate': True},
#     {'location': [103.9, 40.1],
#      'player': {'id': 4648, 'name': 'Abbie McManus'},
#      'position': {'id': 3, 'name': 'Right Center Back'},
#      'teammate': True},
#     {'location': [103.7, 42.3],
#      'player': {'id': 31702, 'name': 'Rianna Dean'},
#      'position': {'id': 16, 'name': 'Left Midfield'},
#      'teammate': True},
#     {'location': [92.1, 54.1],
#      'player': {'id': 5078, 'name': 'Alanna Stephanie Kennedy'},
#      'position': {'id': 9, 'name': 'Right Defensive Midfield'},
#      'teammate': True}]}}]

# %%
if events:
    # Get a list of all event_ids for the current match
    event_ids = [event['id'] for event in events]
    
    # Fetch existing events in bulk
    existing_event_ids = events_collection.find({'id': {'$in': event_ids}}, {'id': 1})
    existing_event_ids = {event['id'] for event in existing_event_ids}
    
    # Filter out events that are already in the database
    new_events = [event for event in events if event['id'] not in existing_event_ids]

    # Insert new events in bulk
    if new_events:
        events_collection.insert_many(new_events)
        print(f"Inserted {len(new_events)} new {event_type} events for match {match_id} into MongoDB.")
    else:
        print(f"No new {event_type} events for match {match_id}.")
else:
    print(f"No {event_type} events found for match {match_id}.")
